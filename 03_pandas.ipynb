# %% [markdown]
# # FUNDAMENTALS OF DATA ANALYSIS WITH PYTHON <br><font color="crimson">DAY 3: SOCIAL SCIENTIFIC COMPUTING WITH PANDAS</font>
#
# 49th [GESIS Spring Seminar: Digital Behavioral Data](https://training.gesis.org/?site=pDetails&pID=0xA33E4024A2554302B3EF4AECFC3484FD)
# Cologne, Germany, March 2-6 2010
#
# ### Course Developers and Instructors
#
# * Dr. [John McLevey](www.johnmclevey.com), University of Waterloo (john.mclevey@uwaterloo.ca)
# * [Jillian Anderson](https://ca.linkedin.com/in/jillian-anderson-34435714a?challengeId=AQGaFXECVnyVqAAAAW_TLnwJ9VHAlBfinArnfKV6DqlEBpTIolp6O2Bau4MmjzZNgXlHqEIpS5piD4nNjEy0wsqNo-aZGkj57A&submissionId=16582ced-1f90-ec15-cddf-eb876f4fe004), Simon Fraser University (jillianderson8@gmail.com)
#
# <hr>
#
# ## <i class="fa fa-tasks"></i> OVERVIEW
#
# This notebook introduces some fundamentals of scientific computing with `Pandas` and `matplotlib`. `Pandas` is an extremely popular Python package for storing, manipulating, and analyzing data in a tabular form, with rows and columns. We will learn how to get data into `pandas`, and then how to perform common data analysis tasks such as selecting columns, filtering rows, and computing descriptive statistics. Then we will learn how to use `matplotlib` for producing high-quality plots for print or the web. We will use it to create a variety of common statistical plots and other visualizations.
#
# As with yesterday, this notebook contains more information than we will likely be able to cover in a day. Depending on your experience, expertise, and research needs, we may jump around the notebook a bit to best "meet you where you are." We hope that including a lot of narrative text will provide you with enough background to start working effectively with `pandas` in the context of real research projects.
#
# ## <i class="fa fa-map-o"></i> PLAN FOR THE DAY
#
# <i class="fa fa-location-arrow"></i> [`Pandas` 101](#pandas)
# <i class="fa fa-location-arrow"></i> [Aggregation & Grouped Operations](#agg)
# <i class="fa fa-location-arrow"></i> [Sorting & Ranking](#sort)
# <i class="fa fa-location-arrow"></i> [Correlation and Covariance](#corr)
# <i class="fa fa-location-arrow"></i> [Dates & Times](#date)
# <i class="fa fa-location-arrow"></i> [Missing Data](#miss)
# <i class="fa fa-location-arrow"></i> [Working with Multiple Datasets](#multi)
# <hr>

# %%
import os
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg' # better resolution with vector graphics!

# %% [markdown]
# # <i class="fa location-arrow"></i> `Pandas` 101<a id='pandas'></a>
#
# Quantitative or computational social scientists are used to working with data in tabular form, such as a `dataframe` with variables in the columns and observations in the rows. In Python, the `Pandas` package enables us to organize, manipulate, and analyze data in this familiar way.
#
# `Pandas` is an extremely popular package in the scientific computing community regardless of the discipline (physics, sociology, neuroscience, history) or industry (academia, government, industry). It was originally developed for time series analysis. It gets it's name from **pan**el **da**ta.
#
# This part of the notebook covers some essential functionality of `Pandas` that you will make heavy use of in most data analyses. Of course, we will not cover *everything* that is possible to do with `Pandas`. As with the previous content, the goal is to build a basic foundation that we can build on throughout the week. We will emphasize the functionality that can take you the furthest in any given data analysis project.
#
# # <i class="fa fa-location-arrow"></i> READING DATA FROM FILES
#
# `Pandas` makes it easy to load data from an external file directly into a `DataFrame`, which will discuss momentarily. It does so using one of many `reader` functions that are part of a suite of `I/O` (input / output, read / write) tools. For some common examples, see the table below. Information on these and other `reader` functions can be found in the `pandas` [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html). The [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) also provides useful information about the parameters for these methods, such as how to specify what sheet you want from an Excel spreadsheet, or whether to write the index to a new `csv` file.
#
#
#
# | Data Description                | Reader          | Writer        |
# |:--------------------------------|:----------------|:--------------|
# | CSV                             | `read_csv()`   | `to_csv()`   |
# | JSON                            | `read_json()`  | `to_json()`  |
# | MS Excel and OpenDocument (ODF) | `read_excel()` | `to_excel()` |
# | Stata                           | `read_stata()` | `to_stata()` |
# | SAS                             | `read_sas()`   | NA            |
# | SPSS                            | `read_spss()`  | NA            |
#
#
# To illustrate how these `reader` functions work, we will use the `read_csv()` function. The only *required* argument is that we provide the path to the location of the file on our computer.
#
# In this case, we will use the ["Three Million Russian Trolls" dataset](https://fivethirtyeight.com/features/why-were-sharing-3-million-russian-troll-tweets/), which consists of data on ~3M tweets from Twitter accounts that are known to be part of state-sponsored disinformation campaigns. This particular dataset was collected and coded by Darrin Linvill and Patrick Warren, of Clemson University. It includes several variables that were hand coded by Linvill and Warren, the most important of which are classifications of accounts into different types.
#
# The dataset is stored in 12 different `csv` files. They are stored in a directory called `russian-troll-tweets`, which is inside the `data` directory.

# %%
# !ls data/russian-troll-tweets
os.listdir('data/russian-troll-tweets')
# Out:
# ['README.md',
#  'IRAhandle_tweets_10.csv',
#  'IRAhandle_tweets_11.csv',
#  'IRAhandle_tweets_5.csv',
#  '.git',
#  'IRAhandle_tweets_7.csv',
#  'IRAhandle_tweets_8.csv',
#  'IRAhandle_tweets_6.csv',
#  'IRAhandle_tweets_9.csv',
#  'IRAhandle_tweets_2.csv',
#  'IRAhandle_tweets_3.csv',
#  'IRAhandle_tweets_1.csv',
#  'IRAhandle_tweets_13.csv',
#  'IRAhandle_tweets_4.csv',
#  'IRAhandle_tweets_12.csv']

# %% [markdown]
# Let's start by loading just one of the files. Later we will see how to read in all 12 and combine them into 1 large dataset.

# %%
df = pd.read_csv('data/russian-troll-tweets/IRAhandle_tweets_1.csv')

# %% [markdown]
# By default, `pandas` assumes your data is encoded with `UTF-8`. If you see an encoding error, you can switch to a different encoding, such as `latin`.
#
# Once we have our `dataframe`, we can use the `info()` method to see the name of each column, as well as it's integer index and datatype.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243891 entries, 0 to 243890
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   external_author_id  243891 non-null  int64
#  1   author              243891 non-null  object
#  2   content             243891 non-null  object
#  3   region              243853 non-null  object
#  4   language            243891 non-null  object
#  5   publish_date        243891 non-null  object
#  6   harvested_date      243891 non-null  object
#  7   following           243891 non-null  int64
#  8   followers           243891 non-null  int64
#  9   updates             243891 non-null  int64
#  10  post_type           154592 non-null  object
#  11  account_type        243891 non-null  object
#  12  retweet             243891 non-null  int64
#  13  account_category    243891 non-null  object
#  14  new_june_2018       243891 non-null  int64
#  15  alt_external_id     243891 non-null  int64
#  16  tweet_id            243891 non-null  int64
#  17  article_url         243891 non-null  object
#  18  tco1_step1          180520 non-null  object
#  19  tco2_step1          66432 non-null   object
#  20  tco3_step1          2803 non-null    object
# dtypes: int64(8), object(13)
# memory usage: 39.1+ MB

# %% [markdown]
# We now have a `dataframe` with 21 variables. The `dataframe` is organized as we would expect: with variables in the columns and observations in the columns. We can use the `.head()` method to preview the top $n$ rows of the dataset.

# %%
df.head(10)
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
# 5  906000000000000000  10_GOP
# 6  906000000000000000  10_GOP
# 7  906000000000000000  10_GOP
# 8  906000000000000000  10_GOP
# 9  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
# 5  Dan Bongino: "Nobody trolls liberals better th...  Unknown  English
# 6                        🐝🐝🐝 https://t.co/MorL3AQW0z  Unknown  English
# 7  '@SenatorMenendez @CarmenYulinCruz Doesn't mat...  Unknown  English
# 8  As much as I hate promoting CNN article, here ...  Unknown  English
# 9  After the 'genocide' remark from San Juan Mayo...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates  ...  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253  ...
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254  ...
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255  ...
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642      256  ...
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645      246  ...
# 5   10/1/2017 2:47   10/1/2017 2:47       1050       9644      247  ...
# 6   10/1/2017 2:48   10/1/2017 2:48       1050       9644      248  ...
# 7   10/1/2017 2:52   10/1/2017 2:53       1050       9644      249  ...
# 8   10/1/2017 3:47   10/1/2017 3:47       1050       9646      250  ...
# 9   10/1/2017 3:51   10/1/2017 3:51       1050       9646      251  ...
#
#   account_type retweet  account_category new_june_2018     alt_external_id  \
# 0        Right       0        RightTroll             0  905874659358453760
# 1        Right       0        RightTroll             0  905874659358453760
# 2        Right       1        RightTroll             0  905874659358453760
# 3        Right       0        RightTroll             0  905874659358453760
# 4        Right       1        RightTroll             0  905874659358453760
# 5        Right       0        RightTroll             0  905874659358453760
# 6        Right       1        RightTroll             0  905874659358453760
# 7        Right       0        RightTroll             0  905874659358453760
# 8        Right       0        RightTroll             0  905874659358453760
# 9        Right       0        RightTroll             0  905874659358453760
#
#              tweet_id                                        article_url  \
# 0  914580356430536707  http://twitter.com/905874659358453760/statuses...
# 1  914621840496189440  http://twitter.com/905874659358453760/statuses...
# 2  914623490375979008  http://twitter.com/905874659358453760/statuses...
# 3  914639143690555392  http://twitter.com/905874659358453760/statuses...
# 4  914312219952861184  http://twitter.com/905874659358453760/statuses...
# 5  914320835325853696  http://twitter.com/905874659358453760/statuses...
# 6  914321156466933760  http://twitter.com/905874659358453760/statuses...
# 7  914322215537119234  http://twitter.com/905874659358453760/statuses...
# 8  914335818503933957  http://twitter.com/905874659358453760/statuses...
# 9  914336862730375170  http://twitter.com/905874659358453760/statuses...
#
#                                           tco1_step1 tco2_step1 tco3_step1
# 0  https://twitter.com/10_gop/status/914580356430...        NaN        NaN
# 1  https://twitter.com/damienwoody/status/9145685...        NaN        NaN
# 2  https://twitter.com/10_gop/status/913231923715...        NaN        NaN
# 3  https://twitter.com/10_gop/status/914639143690...        NaN        NaN
# 4  https://twitter.com/realDonaldTrump/status/914...        NaN        NaN
# 5  https://twitter.com/FoxNews/status/91423949678...        NaN        NaN
# 6  https://twitter.com/Cernovich/status/914314644...        NaN        NaN
# 7                                                NaN        NaN        NaN
# 8  http://www.cnn.com/2017/09/27/us/puerto-rico-a...        NaN        NaN
# 9                                                NaN        NaN        NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# Alternatively, we could use the `.sample()` method to pull a random sample of $n$ observations, which can be helpful if we don't want the observations we preview to be from the top (`head`) or bottom (`tail`) of the dataset.

# %%
df.sample(10)
# Out:
#         external_author_id         author  \
# 50793   893000000000000000       ALAXXATR
# 22305           1652138929       ACEJINEV
# 22625           1652138929       ACEJINEV
# 103228          1679279490  AMELIEBALDWIN
# 222025          1671936266     ARM_2_ALAN
# 7583            4036537452       4MYSQUAD
# 38122           1657833811    ADRIENNE_GG
# 157703  895000000000000000    ANGEELISHET
# 207797          2415574043   ARINA_RONDAL
# 55200   802673000000000000  ALBUQUERQUEON
#
#                                                   content         region  \
# 50793   #aleex Watch Rocker Ted Nugent PASSIONATELY De...        Unknown
# 22305   New Edition:: Saviours' Day 2017: The Nation O...  United States
# 22625   Purchase some inspirational headgear at my sho...  United States
# 103228  '@2_Legit2_Quit_ did you see this?   #Wikileak...  United States
# 222025  Court overturns some Blagojevich Senate-seat c...  United States
# 7583    Is this for real? Dozens of killer cops were c...  United States
# 38122   A friend is someone who knows all about you an...  United States
# 157703  #angees BREAKING : Trump Just Tweeted a BRUTAL...        Unknown
# 207797  Минкульт предупредил «Артдокфест» о последстви...  United States
# 55200   City of Albuquerque and elementary school fall...        Unknown
#
#        language     publish_date   harvested_date  following  followers  \
# 50793   English  8/17/2017 16:20  8/17/2017 16:20         28          2
# 22305   English   2/8/2017 13:57   2/8/2017 13:57        788        908
# 22625   English  3/17/2017 14:03  3/17/2017 14:03        785        915
# 103228  English  11/16/2016 8:26  11/16/2016 8:26       2385       2548
# 222025  English  7/21/2015 23:11  7/21/2015 23:12         65        152
# 7583    English  4/15/2016 20:54  4/15/2016 20:54       4653       3860
# 38122   English  3/16/2015 14:41  3/16/2015 14:41        150        142
# 157703  English   8/9/2017 12:44   8/9/2017 12:44         50          1
# 207797  Russian  12/8/2015 16:17  12/8/2015 16:19        160        252
# 55200   English   4/7/2017 13:27   4/7/2017 13:27       4576        533
#
#         updates  ... account_type retweet  account_category new_june_2018  \
# 50793       694  ...        Right       0        RightTroll             0
# 22305      4186  ...         Left       1         LeftTroll             0
# 22625      5064  ...         Left       1         LeftTroll             0
# 103228    18092  ...        Right       1        RightTroll             0
# 222025    11621  ...        Right       1        RightTroll             0
# 7583       1254  ...         Left       0         LeftTroll             0
# 38122       674  ...    Hashtager       0      HashtagGamer             0
# 157703       50  ...        Right       0        RightTroll             0
# 207797     2537  ...      Russian       1        NonEnglish             1
# 55200      2675  ...        local       0          NewsFeed             1
#
#            alt_external_id            tweet_id  \
# 50793   893396485555048448  898217905963380736
# 22305           1652138929  829328232881209344
# 22625           1652138929  842738205401190400
# 103228          1679279490  798804347656159232
# 222025          1671936266  623631536554774528
# 7583            4036537452  721079168172036096
# 38122           1657833811  577479781496823808
# 157703  894823022317752320  895264420439445505
# 207797          2415574043  674261483438678016
# 55200   802673478130434048  850339136095604736
#
#                                               article_url  \
# 50793   http://twitter.com/893396485555048448/statuses...
# 22305   http://twitter.com/1652138929/statuses/8293282...
# 22625   http://twitter.com/1652138929/statuses/8427382...
# 103228  http://twitter.com/1679279490/statuses/7988043...
# 222025  http://twitter.com/Arm_2_Alan/statuses/6236315...
# 7583    http://twitter.com/4MySquad/statuses/721079168...
# 38122   http://twitter.com/Adrienne_GG/statuses/577479...
# 157703  http://twitter.com/894823022317752320/statuses...
# 207797  http://twitter.com/arina_rondal/statuses/67426...
# 55200   http://twitter.com/802673478130434048/statuses...
#
#                                                tco1_step1  \
# 50793   https://twitter.com/alaxxaTR/status/8982179059...
# 22305   https://twitter.com/TheFinalCall/status/828941...
# 22625   https://twitter.com/TariqToure/status/84206288...
# 103228  https://twitter.com/Roni_K_Patriot/status/7987...
# 222025                                http://dld.bz/dMCJJ
# 7583    https://twitter.com/4MySquad/status/7210791681...
# 38122                                                 NaN
# 157703  https://twitter.com/angeelisHET/status/8952644...
# 207797  https://twitter.com/meduzaproject/status/67424...
# 55200   https://twitter.com/AlbuquerqueOn/status/85033...
#
#                                                tco2_step1 tco3_step1
# 50793                               http://ift.tt/2wTg4cx        NaN
# 22305                         http://FinalCallDigital.com        NaN
# 22625             http://ln.is/www.tariqtoure.com/s/MuMXv        NaN
# 103228  https://wikileaks.org/podesta-emails/emailid/5...        NaN
# 222025                                                NaN        NaN
# 7583                                 http://goo.gl/DLca0f        NaN
# 38122                                                 NaN        NaN
# 157703                              http://ift.tt/2up07gH        NaN
# 207797  https://meduza.io/news/2015/12/08/minkultury-p...        NaN
# 55200   http://krqe.com/2017/04/07/city-of-albuquerque...        NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# To load up the full dataset -- which is spread across 12 files -- we can read in each `csv` file and concatenate them all into a single `dataframe`. Note that if your data is contained in a single file, this step would not be necessary.

# %%
data_dir = os.listdir('data/russian-troll-tweets')
data_dir
# Out:
# ['README.md',
#  'IRAhandle_tweets_10.csv',
#  'IRAhandle_tweets_11.csv',
#  'IRAhandle_tweets_5.csv',
#  '.git',
#  'IRAhandle_tweets_7.csv',
#  'IRAhandle_tweets_8.csv',
#  'IRAhandle_tweets_6.csv',
#  'IRAhandle_tweets_9.csv',
#  'IRAhandle_tweets_2.csv',
#  'IRAhandle_tweets_3.csv',
#  'IRAhandle_tweets_1.csv',
#  'IRAhandle_tweets_13.csv',
#  'IRAhandle_tweets_4.csv',
#  'IRAhandle_tweets_12.csv']

# %%
files = [f for f in data_dir if 'csv' in f]
files
# Out:
# ['IRAhandle_tweets_10.csv',
#  'IRAhandle_tweets_11.csv',
#  'IRAhandle_tweets_5.csv',
#  'IRAhandle_tweets_7.csv',
#  'IRAhandle_tweets_8.csv',
#  'IRAhandle_tweets_6.csv',
#  'IRAhandle_tweets_9.csv',
#  'IRAhandle_tweets_2.csv',
#  'IRAhandle_tweets_3.csv',
#  'IRAhandle_tweets_1.csv',
#  'IRAhandle_tweets_13.csv',
#  'IRAhandle_tweets_4.csv',
#  'IRAhandle_tweets_12.csv']

# %%
df['used_to_be_the_index'] = df.index

# %%
df.index == df['used_to_be_the_index']
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %% [markdown]
# We will overwrite the `df` created earlier.

# %%
df = pd.concat((pd.read_csv('data/russian-troll-tweets/{}'.format(f), encoding='utf-8', low_memory=False) for f in files if 'csv' in f), ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2946207 entries, 0 to 2946206
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   external_author_id  object
#  1   author              object
#  2   content             object
#  3   region              object
#  4   language            object
#  5   publish_date        object
#  6   harvested_date      object
#  7   following           int64
#  8   followers           int64
#  9   updates             int64
#  10  post_type           object
#  11  account_type        object
#  12  retweet             int64
#  13  account_category    object
#  14  new_june_2018       int64
#  15  alt_external_id     object
#  16  tweet_id            int64
#  17  article_url         object
#  18  tco1_step1          object
#  19  tco2_step1          object
#  20  tco3_step1          object
# dtypes: int64(6), object(15)
# memory usage: 472.0+ MB

# %%
sample = df.sample(4000)
sample.to_csv('data/sample.csv', index=False)

# %% [markdown]
# In this case, we have two datatypes in our `dataframe`: `object` and `int64`. `Pandas` uses `object` to refer to columns that contain `strings`, or which contain mixed types, such as `strings` and `integers`. In this case, they refer to `strings`. `int64` are integers. In addition to these two data types, `pandas` stores `floats` (`float64`), booleans (True or False), several specialized `datetime` data structures, and categorical variables.
#
# One further thing to note about this dataset: **each row is a tweet from a specific account, but some of the variables describe attributes of the tweeting accounts, not of the tweet itself**. For example, `followers` describes the number of followers that the account had at the time it sent the tweet. This makes sense, because tweets don't have followers, but accounts do. We need to keep this in mind when working with this dataset.

# %% [markdown]
# <a id='struct'></a>
# # <i class="fa fa-location-arrow"></i> UNDERSTANDING `PANDAS` DATA STRUCTURES
#
# Now that we have a `dataframe` loaded into memory, we can move on to some interesting data analyses. But first, let's devote a bit of time to clarifying `pandas` data structures.
#
# ### <i class="fa fa-graduation-cap"></i> Dynamic Typing [<i class="fa fa-forward"></i>](#skip_dynamic)
#
# > Note: feel free to use the [<i class="fa fa-forward"></i>](#essential_series) button above to temporarily [skip](#essential_series) over this "background knowledge" section if you are feeling overwhelmed with new information. It is useful to know, but it is not *essential* knowledge for using Pandas to analyze data. You will not lose much if you come back to this at some point in the future, when you are more comfortable with basic `pandas` data structures and operations.
#
# First, some background knowledge. Python is a dynamically typed language. What that means is that you don't need to constantly tell Python what kind of object something is. For example, if you add two numbers together

# %%
42 + 8
# Out:
# 50

# %% [markdown]
# it is not necessary to tell Python that `42` and `8` are integers. Instead, Python stores that metadata in each object.
#
# When we store data in a list, every element in the list is actually a Python object itself, containing not only the actual data itself (e.g. `42`), but also information about the **type** of data that it is, which in this case is `int64`. This is enormously useful in many cases, because we store objects of different types in a `list`.

# %%
some_data = [42, 8.0, 'a string']
print(some_data)
# Out:
# [42, 8.0, 'a string']

# %% [markdown]
# In this example, each element in `some_data` also contains information about the type of object it is. As previously mentioned, this is enormously helpful in some contexts, but dramatically slows down computation in other contexts. Data analysis is one example of where, depending on what you are trying to do, dynamic typing can slow things down rather a lot.
#
# When you are analyzing data, you are almost always working with some collection of elements that are all of the same type, such as integers, floats, strings, or Boolean values. For example, you can't compute the mean and standard deviation of a collection of elements that include both integers and strings. So it follows that data analysis can be made more efficient by working on data structures where information about data types is stored at the level of the collection itself rather than each element in the collection, *provided the data is all of the same type*.
#
# One of the main tools for doing this in `Python` is the `numpy` package, which is more or less the foundation of all data analysis in `Python`, whether you explicitly use it or not. `numpy` provides data structures for working with `arrays` of data that are a bit like lists except that all elements are of the same type, information about that type is stored at the level of the `array` itself, and each element in the `array` has an explicit integer index. `arrays` can be one dimensional vectors or multi-dimensional matrices.
#
# Further discussion of `numpy` is beyond the scope of this class. For our purposes here, what you need to know is that `pandas` builds on top of `numpy` and offers an additional set of data structures and methods that are designed explicitly to meet the needs to researchers working with real-world empirical data. Like `numpy`, `pandas` is designed to make scientific computing more efficient, but as we will learn below there are some common pitfalls to avoid that, if you are not careful, can actually make working with `pandas` slow and inefficient.

# %% [markdown]
# <a id='skip_dynamic'></a><a id='series_index'></a>
# # <i class="fa fa-location-arrow"></i> `Series` and `index`
#
# Each column in a `dataframe` is an object called a `series`. A `series` is a one-dimensional object, such as a vector of numbers. However, that vector is associated with an `index`, which is a vector, or array, of labels.
#
# For example, the column `retweet` in our Russian troll `dataframe` is a `series` of integers (number of times a tweet was retweeted) and their `index` labels.

# %%
num_followers = df['followers']
type(num_followers)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Below, we pull a sample of 25 tweets from the `series`. The value on the left is the index label for the observation, the number on the right is the actual data value (number of retweets). The index values are sequential in the actual `series`, but they are out of sequence here because we pulled a random sample.

# %%
num_followers.sample(25)
# Out:
# 2715994         4
# 158996      12322
# 2906406      7385
# 1346386       322
# 1725875       426
# 177865         75
# 1116826      4029
# 1718142      7285
# 700932       1075
# 2025259       404
# 1498710    107849
# 2012631       159
# 2276520       368
# 2440522       916
# 1619925      1809
# 2521997     20163
# 2391265       298
# 1649599     13493
# 1987078      1010
# 689769        287
# 2400719       152
# 2254155       874
# 2732785      6097
# 2350861     23159
# 21864       17311
# Name: followers, dtype: int64

# %% [markdown]
# In most cases, the default `index` for a `series` or `dataframe` is an immutable vector of integers:

# %%
num_followers.index
# Out:
# RangeIndex(start=0, stop=2946207, step=1)

# %% [markdown]
# In some cases, such as time series analysis, the `index` might default to a `DatetimeIndex` or a `PeriodIndex`, but we will not consider those in this course. If you are working with time series data, the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) provides explanations of how to use these types of `indices`.
#
# We can easily modify an `index` so that it is made of up some other type of vector instead, including a `string`. Surprisingly, `index` values do not need to be unique (technically, they are a `multiset`, or a `set` that is allowed to have repeat elements). This enables us to do some powerful things, but most of the time you should avoid manually changing indexes.
#
# We can use the `index` to retrieve specific values from a `series` much as we would if we were selecting an element from a `list`, `tuple`, or `array`.

# %% [markdown]
# ### Operations on `Series`: Descriptive Statistics
#
# As we will soon see, there are a number of operations we can perform on `Series`, such as simple descriptive statistics like mean, median, mode, and standard deviation.

# %%
print('Median ', num_followers.median())
print('Mean ', num_followers.mean())
print('Standard Deviation ', num_followers.std())
# Out:
# Median  1274.0
# Mean  7055.265491868019
# Standard Deviation  14635.939344600854

# %% [markdown]
# Since the values returned from operations on `Series` are essentially equivalent to a `numpy` `array`, we can use `numpy` methods on `Series` objects. For example, we can use the `round()` method from `numpy` to round these descriptives to a few decimal points.

# %%
print('Median ', np.round(num_followers.median(), 3))
print('Mean ', np.round(num_followers.mean(), 3))
print('Standard Deviation ', np.round(num_followers.std(), 3))
# Out:
# Median  1274.0
# Mean  7055.265
# Standard Deviation  14635.939

# %% [markdown]
# We can also `count` the number of non-missing observations in a `series`

# %%
num_followers.count()
# Out:
# 2946207

# %% [markdown]
# or get an overview of multiple descriptives at once:

# %%
num_followers.describe()
# Out:
# count    2.946207e+06
# mean     7.055265e+03
# std      1.463594e+04
# min     -1.000000e+00
# 25%      3.220000e+02
# 50%      1.274000e+03
# 75%      1.085300e+04
# max      2.512760e+05
# Name: followers, dtype: float64

# %% [markdown]
# If our series is categorical, we can also easily compute useful information such as the number of unique categories, the size of each category, and so on. For example, let's look at the `account_type` `series`.

# %%
atype = df['account_type']

# %%
atype.unique()
# Out:
# array(['Russian', 'Right', 'news', '?', 'Koch', 'Hashtager', 'Left',
#        'German', 'Arabic', 'local', 'Italian', 'Ebola ', 'French',
#        'Commercial', 'Uzbek', 'Spanish', 'Ukranian', 'ZAPOROSHIA',
#        'Portuguese'], dtype=object)

# %%
atype.value_counts()
# Out:
# Right         711668
# Russian       704917
# local         459220
# Left          427141
# Hashtager     241786
# news          139006
# Commercial    121904
# German         91511
# Italian        15680
# ?              13539
# Koch           10894
# Arabic          6228
# Spanish         1226
# French          1117
# ZAPOROSHIA       175
# Portuguese       118
# Ebola             71
# Ukranian           4
# Uzbek              2
# Name: account_type, dtype: int64

# %% [markdown]
# Later, we will consider some summary statistics for pairs of `series`, such as computing correlations and covariance.

# %% [markdown]
# <a id='dataframe'></a>
# # <i class="fa fa-location-arrow"></i> DataFrames
#
# We already have our `DataFrame` loaded into memory (as `df`), but so far all we have used it for is pulling out individual `series`. This is easy to do in part because `DataFrames` are themselves just collections of `Series` that are aligned on the same `index` values. In other words, both `Series` we worked with previously -- `atype` and `num_followers` -- have their own `indexes` when we work with them as `Series`, but in a `DataFrame`, they share an index. `DataFrames` are organized the way we would expect: with variables in the columns and observations in the rows. We can use the `.head()` method to preview the top $n$ rows of the dataset.

# %%
df.tail()
# Out:
#         external_author_id    author  \
# 2946202         2589513234  ZUBOVNIK
# 2946203         2589513234  ZUBOVNIK
# 2946204         2589513234  ZUBOVNIK
# 2946205         2589513234  ZUBOVNIK
# 2946206         2589513234  ZUBOVNIK
#
#                                                    content   region language  \
# 2946202                Нет слов... https://t.co/Q11oaKiJIS  Unknown  Russian
# 2946203  '@VRSoloviev ГУМВД: уголовное дело возбуждено ...  Unknown  Russian
# 2946204  Великое переселение народов продолжается. Неда...  Unknown  Russian
# 2946205  Порошенко вновь просит США поставить вооружени...  Unknown  Russian
# 2946206  Поздравляю Дмитрия Анатольевича с 50-летием Же...  Unknown  Russian
#
#             publish_date   harvested_date  following  followers  updates  ...  \
# 2946202  9/14/2015 17:09  9/14/2015 17:09       3559      22633    13212  ...
# 2946203  9/14/2015 17:57  9/14/2015 17:57       3559      22633    13217  ...
# 2946204   9/14/2015 6:25   9/14/2015 8:42       3563      22629    13192  ...
# 2946205   9/14/2015 6:55   9/14/2015 6:58       3563      22623    13183  ...
# 2946206   9/14/2015 7:23   9/14/2015 7:53       3563      22625    13187  ...
#
#         account_type retweet  account_category new_june_2018  alt_external_id  \
# 2946202      Russian       1        NonEnglish             0       2589513234
# 2946203      Russian       0        NonEnglish             0       2589513234
# 2946204      Russian       0        NonEnglish             0       2589513234
# 2946205      Russian       0        NonEnglish             0       2589513234
# 2946206      Russian       0        NonEnglish             0       2589513234
#
#                    tweet_id  \
# 2946202  643471568635564033
# 2946203  643483758482604032
# 2946204  643309470794260480
# 2946205  643317220395909120
# 2946206  643324060068413440
#
#                                                article_url  \
# 2946202  http://twitter.com/zubovnik/statuses/643471568...
# 2946203  http://twitter.com/zubovnik/statuses/643483758...
# 2946204  http://twitter.com/zubovnik/statuses/643309470...
# 2946205  http://twitter.com/zubovnik/statuses/643317220...
# 2946206  http://twitter.com/zubovnik/statuses/643324060...
#
#                                                 tco1_step1 tco2_step1  \
# 2946202  https://twitter.com/lifenews_ru/status/6434686...        NaN
# 2946203   http://ria.ru/incidents/20150914/1251405308.html        NaN
# 2946204  https://twitter.com/zubovnik/status/6433094707...        NaN
# 2946205  https://twitter.com/zubovnik/status/6433172203...        NaN
# 2946206  https://twitter.com/zubovnik/status/6433240600...        NaN
#
#         tco3_step1
# 2946202        NaN
# 2946203        NaN
# 2946204        NaN
# 2946205        NaN
# 2946206        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Alternatively, we could use the `.sample()` method to pull a random sample of $n$ observations, which can be helpful if we don't want the observations we preview to be from the top (`head`) or bottom (`tail`) of the dataset.

# %%
df.sample(5)
# Out:
#         external_author_id           author  \
# 190969          1652262638      ANTONHAYHAY
# 214994          1671936266       ARM_2_ALAN
# 141385  871000000000000000  ANDIOSMARRTRUMP
# 216546          3438999494  WORLDOFHASHTAGS
# 64699           2572531545   TRYTOFINDITOUT
#
#                                                   content         region  \
# 190969  Cavs get a lead with great ball movement, then...  United States
# 214994  Woman maybe was shoved on tracks for being tra...  United States
# 141385  The bad blood between Taylor Swift and Spotify...        Unknown
# 216546  People who introduce their vegan lifestyle or ...  United States
# 64699                  #My4WordMotto Don't touch my phone  United States
#
#        language     publish_date   harvested_date  following  followers  \
# 190969  English  4/23/2017 19:40  4/23/2017 19:40        301        745
# 214994  English   6/3/2015 19:34   6/3/2015 19:34         68        113
# 141385  English   6/10/2017 0:56   6/10/2017 0:56       2866        420
# 216546  English  8/24/2016 14:22  8/24/2016 14:22       6355       6206
# 64699   English   1/4/2016 14:21   1/4/2016 14:21       1451       1852
#
#         updates  ... account_type retweet  account_category new_june_2018  \
# 190969    10063  ...         Left       1         LeftTroll             0
# 214994     1688  ...        Right       1        RightTroll             0
# 141385      278  ...        Right       0        RightTroll             0
# 216546    16703  ...    Hashtager       1      HashtagGamer             0
# 64699      1783  ...    Hashtager       1      HashtagGamer             0
#
#            alt_external_id            tweet_id  \
# 190969          1652262638  856231375137058821
# 214994          1671936266  606182091148165120
# 141385  870647274833145857  873342976482840576
# 216546          3438999494  768453407208304640
# 64699           2572531545  684016794961444865
#
#                                               article_url  \
# 190969  http://twitter.com/1652262638/statuses/8562313...
# 214994  http://twitter.com/Arm_2_Alan/statuses/6061820...
# 141385  http://twitter.com/870647274833145857/statuses...
# 216546  http://twitter.com/WorldOfHashtags/statuses/76...
# 64699   http://twitter.com/TrytofinditOut/statuses/684...
#
#                                                tco1_step1  \
# 190969                                                NaN
# 214994                                                NaN
# 141385  https://twitter.com/EissyT56T/status/873341733...
# 216546                                                NaN
# 64699                                                 NaN
#
#                                                tco2_step1 tco3_step1
# 190969                                                NaN        NaN
# 214994                                                NaN        NaN
# 141385  https://twitter.com/safety/unsafe_link_warning...        NaN
# 216546                                                NaN        NaN
# 64699                                                 NaN        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# When working with a `dataframe`, we can select subsets of data by selecting columns or filtering rows. Let's look at selecting columns first.
#
# ### Selecting Columns
#
# Earlier, we saw how we could select a single column using by specifying the name of the `dataframe` followed by the name of the `series` inside square brackets and straight quotes.

# %%
followers = df['followers']
followers.sample(10)
# Out:
# 127842      235
# 24232       267
# 70247      5059
# 85629     16725
# 159602      772
# 109383      540
# 106433      895
# 149613      248
# 1130         47
# 219464    18832
# Name: followers, dtype: int64

# %% [markdown]
# We can select multiple columns by passing a list of column names. Whereas the result of the previous selection was a `Series` (because we only pulled one column), selecting multiple columns will return a `DataFrame` containing only the requested columns.

# %%
ff = df[['followers', 'following']]
ff.sample(10)
# Out:
#          followers  following
# 2297103       2449       1944
# 2425694        291       1663
# 1851742       2312       2848
# 1544812        656        499
# 2932551       2314       2102
# 450490       16995       8717
# 2875730       2118       4907
# 118057         720        706
# 2265712       2109        134
# 2748983       2507       2659

# %% [markdown]
# This kind of subsetting can be very helpful when, for example, you are working with datasets that have a lot of columns, only some of which are required for your analysis.
#
# ### Filtering Rows
#
# It is also sometimes necessary to filter rows. There are a variety of ways to do this, including slices (e.g. all observations between index $i_i$ and index $i_j$). In a data analysis context, most of the row filtering you will do is likely to be based on some sort of explicit condition, such as "give me all the observations with more than 1,000 followers." Most likely, you will only filter rows based on subsets if you are selecting the first $n$ rows of a `DataFrame` that has been sorted by the values of some `Series`. We will consider this case later.

# %%
df[df['followers'] >= 1000].sample(10)
# Out:
#        external_author_id          author  \
# 179013         2530830345    NEWORLEANSON
# 81803          1696996141      KENCANNONE
# 215309         2912754262     PIGEONTODAY
# 192964         3049228218  LUGANSKNOVOSTI
# 188232         2620614029  PHILADELPHIAON
# 119100         1510488662       LAGONEHOE
# 127151         1687183549  BLEEPTHEPOLICE
# 186660         2928870434   NEWSPEAKDAILY
# 92386          2951556370   SPECIALAFFAIR
# 229699         2882331822     JENN_ABRAMS
#
#                                                   content         region  \
# 179013  #politics Carson: Use 'truth serum' on terror ...  United States
# 81803            Disgusting pile of garbage #2016In4Words  United States
# 215309  French interior minister: Anti-terrorism prose...  United States
# 192964  #ВСУ обстреливают районы сел Красный Лиман и П...  United States
# 188232  ACLU Of Pennsylvania Launching Its First Ever ...  United States
# 119100                       yup. https://t.co/hw8CUfeGHF  United States
# 127151  #MichaelJackson once told #Oprah he didn’t wan...  United States
# 186660  AstraZeneca diabetes drug combination faces de...  United States
# 92386   Obama and Putin to meet; Syria and Ukraine vie...  United States
# 229699  CNN caught staging a fake news video https://t...  United States
#
#        language      publish_date    harvested_date  following  followers  \
# 179013  English   2/23/2016 22:13   2/23/2016 22:13      15347      26484
# 81803   English  12/28/2016 16:03  12/28/2016 16:03       2975       2663
# 215309  English    8/22/2015 2:00    8/22/2015 2:00      13800      17474
# 192964  Russian   3/14/2017 15:27   3/14/2017 16:45       3175      48931
# 188232  English    4/25/2017 1:24    4/25/2017 1:24       8867      16704
# 119100  English   7/21/2017 21:50   7/21/2017 21:50       2290       2964
# 127151  English    5/26/2016 1:57    5/26/2016 1:57       6006       8413
# 186660  English   10/16/2015 9:20   10/16/2015 9:20        922       5813
# 92386   English   9/24/2015 20:29   9/24/2015 20:29      10372      12001
# 229699  English    6/7/2017 10:18    6/7/2017 10:18      23708      70227
#
#         updates  ... account_type retweet  account_category new_june_2018  \
# 179013    41882  ...        local       0          NewsFeed             0
# 81803      2835  ...    Hashtager       1      HashtagGamer             0
# 215309     5205  ...        Right       0        RightTroll             0
# 192964     8105  ...      Russian       0        NonEnglish             1
# 188232    16051  ...        local       0          NewsFeed             0
# 119100     4911  ...         Left       1         LeftTroll             0
# 127151    10350  ...         Left       1         LeftTroll             0
# 186660     2332  ...         news       0          NewsFeed             0
# 92386     10218  ...         news       0          NewsFeed             0
# 229699    24641  ...        Right       1        RightTroll             0
#
#         alt_external_id            tweet_id  \
# 179013       2530830345  702255053667569664
# 81803        1696996141  814139717818126336
# 215309       2912754262  634907912985448449
# 192964       3049228218  841672108715450368
# 188232       2620614029  856680197260816384
# 119100       1510488662  888516514336387074
# 127151       1687183549  735651051659878400
# 186660       2928870434  654949968818499586
# 92386        2951556370  647145928307019776
# 229699       2882331822  872397397615407104
#
#                                               article_url  \
# 179013  http://twitter.com/NewOrleansON/statuses/70225...
# 81803   http://twitter.com/1696996141/statuses/8141397...
# 215309  http://twitter.com/PigeonToday/statuses/634907...
# 192964  http://twitter.com/3049228218/statuses/8416721...
# 188232  http://twitter.com/2620614029/statuses/8566801...
# 119100  http://twitter.com/1510488662/statuses/8885165...
# 127151  http://twitter.com/BleepThePolice/statuses/735...
# 186660  http://twitter.com/NewspeakDaily/statuses/6549...
# 92386   http://twitter.com/SpecialAffair/statuses/6471...
# 229699  http://twitter.com/2882331822/statuses/8723973...
#
#                                                tco1_step1  \
# 179013                                                NaN
# 81803                                                 NaN
# 215309  https://twitter.com/PigeonToday/status/6349079...
# 192964  https://twitter.com/LuganskNovosti/status/8416...
# 188232  https://twitter.com/PhiladelphiaON/status/8566...
# 119100  https://twitter.com/__broke/status/88851199529...
# 127151  https://twitter.com/gloed_up/status/7356124358...
# 186660                                                NaN
# 92386                                                 NaN
# 229699  https://twitter.com/Jenn_Abrams/status/8720602...
#
#                                                tco2_step1 tco3_step1
# 179013                                                NaN        NaN
# 81803                                                 NaN        NaN
# 215309                                                NaN        NaN
# 192964                                                NaN        NaN
# 188232  http://philadelphia.cbslocal.com/2017/04/24/ac...        NaN
# 119100                                                NaN        NaN
# 127151                                                NaN        NaN
# 186660                                                NaN        NaN
# 92386                                                 NaN        NaN
# 229699                                                NaN        NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# Alternatively, we could filter based on membership in some category, such as being a `RightTroll` or `LeftTroll` account. `RightTroll` and `LeftTroll` are attributes of the `account_category` `series`. Let's get `RightTroll` accounts.

# %%
df[df['account_category'] == 'RightTroll'].sample(10)
# Out:
#         external_author_id           author  \
# 140990  867000000000000000       COLJASON94
# 29331   892000000000000000         CHAASNTR
# 226818          1676481360      EMILEEWAREN
# 68373   892000000000000000        DANISSTRS
# 113990          1667487494       RIOGITHIEF
# 47179   898000000000000000      CHARMEESTRS
# 48341   898000000000000000      CHARMEESTRS
# 190841  870000000000000000        EISSYT56T
# 212324          2535818742  HAPPKENDRAHAPPY
# 155875          2572058134    LEROYLOVESUSA
#
#                                                   content         region  \
# 140990                Pray for #ManchesterBombing victims  United States
# 29331                    af76ad809d204f4 Thnx for sharing        Unknown
# 226818  They're vandalizing churches They're inciting ...  United States
# 68373   #danita Trump Supporters Demand GOP Traitors D...        Unknown
# 113990  Man Up, Campus Christians—Your Timidity Feeds ...  United States
# 47179   Trump Pledges His Own Money to Off-Set Cost of...        Unknown
# 48341   CNN Makes RIDICULOUS Comment on Trump’s UN Spe...        Unknown
# 190841  VIDEO : Jesse Watters Exposes TRUTH About Ille...        Unknown
# 212324  '@UnitedWe_Stay @ClassySnobbb Next time, ask y...  United States
# 155875  RT @RenewUSTweets: MT @maroulakiz :  And my Go...  United States
#
#        language      publish_date    harvested_date  following  followers  \
# 140990  English   5/23/2017 15:10   5/23/2017 15:10         55          1
# 29331   English   8/11/2017 18:13   8/11/2017 18:13       1928       1138
# 226818  English   11/2/2016 20:30   11/2/2016 20:30       1500       1907
# 68373   English   8/30/2017 21:48   8/30/2017 21:48       4997        977
# 113990  English  11/19/2015 14:32  11/19/2015 14:32        546        254
# 47179   English  10/22/2017 18:46  10/22/2017 18:46          0       1889
# 48341   English   9/20/2017 14:28   9/20/2017 14:29       4819       1718
# 190841  English    7/21/2017 3:16    7/21/2017 3:16          1         25
# 212324  English    1/7/2016 17:17    1/7/2016 17:17        262        295
# 155875  English   2/18/2016 11:16   2/18/2016 11:16        824        621
#
#         updates  ... account_type retweet  account_category new_june_2018  \
# 140990        2  ...        Right       0        RightTroll             0
# 29331      5124  ...        Right       0        RightTroll             0
# 226818     2367  ...        Right       1        RightTroll             0
# 68373      4109  ...        Right       0        RightTroll             0
# 113990      721  ...        Right       1        RightTroll             0
# 47179      2632  ...        Right       0        RightTroll             0
# 48341      1136  ...        Right       0        RightTroll             0
# 190841     2101  ...        Right       0        RightTroll             0
# 212324     1590  ...        Right       1        RightTroll             0
# 155875      645  ...        Right       0        RightTroll             0
#
#            alt_external_id            tweet_id  \
# 140990  867033703427354624  867034919192543232
# 29331   891902187130966017  896072101777391620
# 226818          1676481360  793913120976736256
# 68373   891930470212141056  903011641977163777
# 113990          1667487494  667349728267362304
# 47179   898452282181730305  922172242645127170
# 48341   898452282181730305  910511044669341696
# 190841  870497148365754368  888236273990864896
# 212324          2535818742  685148157534146560
# 155875          2572058134  700277736317853696
#
#                                               article_url  \
# 140990  http://twitter.com/867033703427354624/statuses...
# 29331   http://twitter.com/891902187130966017/statuses...
# 226818  http://twitter.com/1676481360/statuses/7939131...
# 68373   http://twitter.com/891930470212141056/statuses...
# 113990  http://twitter.com/riogithief/statuses/6673497...
# 47179   http://twitter.com/898452282181730305/statuses...
# 48341   http://twitter.com/898452282181730305/statuses...
# 190841  http://twitter.com/870497148365754368/statuses...
# 212324  http://twitter.com/happkendrahappy/statuses/68...
# 155875  http://twitter.com/LeroyLovesUSA/statuses/7002...
#
#                                                tco1_step1  \
# 140990                                                NaN
# 29331                                                 NaN
# 226818  https://twitter.com/MissLizzyNJ/status/7938854...
# 68373   https://twitter.com/danisstrs/status/903011641...
# 113990                              http://bit.ly/1cecPkK
# 47179                               http://ift.tt/2ztrdkY
# 48341                               http://ift.tt/2xmUDTA
# 190841  https://twitter.com/EissyT56T/status/888236273...
# 212324                                                NaN
# 155875  https://twitter.com/maroulakiz/status/52143658...
#
#                    tco2_step1 tco3_step1
# 140990                    NaN        NaN
# 29331                     NaN        NaN
# 226818                    NaN        NaN
# 68373   http://ift.tt/2wTzGAB        NaN
# 113990                    NaN        NaN
# 47179                     NaN        NaN
# 48341                     NaN        NaN
# 190841  http://ift.tt/2gOZ0Ap        NaN
# 212324                    NaN        NaN
# 155875                    NaN        NaN
#
# [10 rows x 21 columns]

# %%
df[(df['account_category'] == 'RightTroll') | (df['account_category'] == 'LeftTroll')].sample(10)
# Out:
#         external_author_id         author  \
# 2761630         4859142199  TRAYNESHACOLE
# 1388991         1627096807      JASSSCOTT
# 410442          4224729994        TEN_GOP
# 2402645         1527687456   ARIELSHINING
# 2657216         1665377383     ELIASBRICK
# 512853          1662453998    ERRIVVVVERS
# 61213           1914760610  RAVENICHOLSON
# 1372186         1716228906     JANI_S_JAC
# 389040          1527133837       SUSAYUNG
# 995021          1654347974      MAYMAYMYY
#
#                                                    content         region  \
# 2761630                        ��� https://t.co/7tVlq5nfEF  United States
# 1388991  Verdict du procès en appel #LuxLeaks le 15 mar...  United States
# 410442   "Obama should have gone to #Louisiana days ago...  United States
# 2402645                baby kitties http://t.co/8KOwXGrKEd  United States
# 2657216  �� RT @MisterDew2012: All the ladies say Hooo....  United States
# 512853   Victim of what? I'm fucking awesome, but you o...  United States
# 61213    Sabermetrics didn't put @TimRaines30 into the ...  United States
# 1372186  �� why they arguing like 40 year olds? https:/...  United States
# 389040   No way, no way! Hillary is an � *sarcasm https...  United States
# 995021   How state attorneys general could take down Tr...  United States
#
#         language     publish_date   harvested_date  following  followers  \
# 2761630  English  4/29/2016 13:18  4/29/2016 13:19       4869       4201
# 1388991   French  3/14/2017 20:04  3/14/2017 20:04        309        766
# 410442   English  8/23/2016 18:08  8/23/2016 18:08      23006      26562
# 2402645  Latvian  5/25/2015 16:31  5/25/2015 16:31         78         55
# 2657216  English  12/18/2016 9:52  12/18/2016 9:52        890        823
# 512853   English   7/31/2017 2:58   7/31/2017 2:58        841        839
# 61213    English  1/18/2017 23:27  1/18/2017 23:27        848        810
# 1372186  English  10/6/2016 20:49  10/6/2016 20:49        573        902
# 389040   English  4/17/2016 14:59  4/17/2016 15:00       1175        443
# 995021   English   2/19/2017 1:54   2/19/2017 1:54        821        980
#
#          updates  ... account_type retweet  account_category new_june_2018  \
# 2761630     1940  ...         Left       1         LeftTroll             0
# 1388991     6299  ...         Left       1         LeftTroll             0
# 410442      3224  ...        Right       0        RightTroll             0
# 2402645      339  ...        Right       0        RightTroll             0
# 2657216     2873  ...         Left       1         LeftTroll             0
# 512853      6772  ...         Left       1         LeftTroll             0
# 61213       3292  ...         Left       1         LeftTroll             0
# 1372186     1686  ...         Left       1         LeftTroll             0
# 389040      1014  ...         Left       1         LeftTroll             0
# 995021      4115  ...         Left       1         LeftTroll             0
#
#          alt_external_id            tweet_id  \
# 2761630       4859142199  726037961213509632
# 1388991       1627096807  841741846388871168
# 410442        4224729994  768147872189743104
# 2402645       1527687456  602874647109971969
# 2657216       1665377383  810422464513769472
# 512853        1662453998  891855539885547520
# 61213         1914760610  821861560197009409
# 1372186       1716228906  784133556230578176
# 389040        1527133837  721714805493530624
# 995021        1654347974  833132642321256448
#
#                                                article_url  \
# 2761630  http://twitter.com/TrayneshaCole/statuses/7260...
# 1388991  http://twitter.com/1627096807/statuses/8417418...
# 410442   http://twitter.com/TEN_GOP/statuses/7681478721...
# 2402645  http://twitter.com/ArielShining/statuses/60287...
# 2657216  http://twitter.com/1665377383/statuses/8104224...
# 512853   http://twitter.com/1662453998/statuses/8918555...
# 61213    http://twitter.com/1914760610/statuses/8218615...
# 1372186  http://twitter.com/Jani_s_Jac/statuses/7841335...
# 389040   http://twitter.com/SusaYung/statuses/721714805...
# 995021   http://twitter.com/1654347974/statuses/8331326...
#
#                                                 tco1_step1  \
# 2761630  https://twitter.com/trayneshacole/status/72592...
# 1388991  https://twitter.com/ClaireNouvian/status/83985...
# 410442   https://twitter.com/TEN_GOP/status/76814787218...
# 2402645                        http://youtu.be/OqYmrXBO28E
# 2657216        https://www.youtube.com/watch?v=3GK23f_xtZY
# 512853   https://twitter.com/quakemaster7/status/891839...
# 61213                                                  NaN
# 1372186  https://twitter.com/SayCheese_TV/status/783893...
# 389040   https://twitter.com/JeanetteJing/status/679885...
# 995021   https://twitter.com/Slate/status/8331249252758...
#
#                       tco2_step1 tco3_step1
# 2761630                      NaN        NaN
# 1388991                      NaN        NaN
# 410442                       NaN        NaN
# 2402645                      NaN        NaN
# 2657216                      NaN        NaN
# 512853                       NaN        NaN
# 61213                        NaN        NaN
# 1372186                      NaN        NaN
# 389040                       NaN        NaN
# 995021   http://slate.me/2kAq0W1        NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# We are left with a subset of 711,668 accounts (check yourself: `len(df[df['account_category'] == 'RightTroll'])`) that are classified as `RightTrolls`.

# %% [markdown]
# Take some time to implement a filter of interest to you in the cell below.

# %%
# Your Turn

# %% [markdown]
# ### Removing Duplicates
# One special case of filtering is the ability to remove duplicate rows from a `DataFrame`. This is often required when multiple rows can refer to the same real-world entity, but there are certain values which will remain the constant for each of that entity's rows.
#
# For example, we may be interested in counting the number of accounts related to each region in our Russian Trolls dataset. We would start by selecting the `region` and `author` columns.

# %%
author_region = df[['author', 'region']]
author_region.head(10)
# Out:
#            author         region
# 0  POLITICS_T0DAY  United States
# 1  POLITICS_T0DAY  United States
# 2  POLITICS_T0DAY  United States
# 3  POLITICS_T0DAY  United States
# 4  POLITICS_T0DAY  United States
# 5  POLITICS_T0DAY  United States
# 6  POLITICS_T0DAY  United States
# 7  POLITICS_T0DAY  United States
# 8  POLITICS_T0DAY  United States
# 9  POLITICS_T0DAY  United States

# %% [markdown]
# Some authors have multiple rows in this `DataFrame` since they have authored multiple tweets. If we were count how often each region appears in this dataset, we would over-estimate regions with more prolific tweeters.
#
# Instead, we will de-duplicate the `DataFrame`.

# %%
author_region.drop_duplicates()
# Out:
#                 author                region
# 0       POLITICS_T0DAY         United States
# 13673   POLITICS__2014  United Arab Emirates
# 14894        POLITKACH  United Arab Emirates
# 15740       POLITOPROS               Unknown
# 15741       POLITOPROS                   NaN
# ...                ...                   ...
# 234249     ZOLLIELEMON         United States
# 234346      ZOTOVA_UNO               Unknown
# 234404        ZSHAANNA  United Arab Emirates
# 234910        ZUBOVNIK                   NaN
# 235632        ZUBOVNIK    Russian Federation
#
# [3236 rows x 2 columns]

# %% [markdown]
# In this case, de-duplication works on the entire row, ignoring the Index. However, if an author tweeted multiple times from different regions we might see that auther continue to appear multiple times in the dataset. This is because even though the author category has duplicates, the combinations of author and region would be unique.
#
# If we want to ensure each author is only included in the dataset once, we can drop duplicates based on a subset of columns.

# %%
author_region.drop_duplicates(subset='author')
# Out:
#                  author                region
# 0        POLITICS_T0DAY         United States
# 13673    POLITICS__2014  United Arab Emirates
# 14894         POLITKACH  United Arab Emirates
# 15740        POLITOPROS               Unknown
# 16331      POLITROS_COM         United States
# ...                 ...                   ...
# 233605         ZLOYKURS               Unknown
# 233711  ZNATNIYBUKHARIK         United States
# 234249      ZOLLIELEMON         United States
# 234346       ZOTOVA_UNO               Unknown
# 234404         ZSHAANNA  United Arab Emirates
#
# [2843 rows x 2 columns]

# %% [markdown]
# In the cell below, use `drop_duplicates` on `df` to determine how many tweets in our dataset have duplicate content.

# %%
# Your Answer Here

# %% [markdown]
# ### Adding New Columns Using Transformations
# Often, we need to add new columns to our `DataFrame` based on values in other columns.

# %%
# df['new_name'] =

# %%
# To save our computers we will use a subset
small_df = df.sample(1000)

# %% [markdown]
# Sometimes, these new columns are transformations of a single column that already exists in the `DataFrame`.
#
# For example, we can create a new `empty_tweet` column. This column, will be `True` when the `content` column is empty and `False` otherwise.

# %%
small_df['empty_tweet'] = small_df['content'].isna()
small_df.sample(5)
# Out:
#         external_author_id         author  \
# 42154           2620869737      PUREDAVIE
# 1622401         1647612534  PASHABORODACH
# 2636047         2586827056    DURADURNOVA
# 743753          1674169892         J_CL_K
# 2928636         2431409855     YANAGREBEN
#
#                                                    content         region  \
# 42154    Wake Me Up Before You Ho Ho #ChristmasAPopSong...  United States
# 1622401  В Татарстане вынесен приговор террористам, кот...        Unknown
# 2636047  На борту потерпевшего крушения Ми-8 находились...        Unknown
# 743753   Hillary: Not a Professional at all #MakeAMovie...  United States
# 2928636  #Осознание@russdem #rus@russdem #Ельцин https:...        Unknown
#
#         language      publish_date    harvested_date  following  followers  \
# 42154    English   12/9/2016 16:57   12/9/2016 16:57       2288       2627
# 1622401  Russian    3/24/2017 4:35    3/24/2017 4:35        166        150
# 2636047  Russian   8/15/2015 12:32   8/15/2015 12:32        267        168
# 743753   English   5/30/2015 13:20   5/30/2015 13:20        259        116
# 2928636  Russian  11/29/2015 21:33  11/29/2015 21:34         98        126
#
#          updates  ... retweet account_category  new_june_2018 alt_external_id  \
# 42154       2407  ...       1     HashtagGamer              0      2620869737
# 1622401      391  ...       1       NonEnglish              0      1647612534
# 2636047     1771  ...       1       NonEnglish              1      2586827056
# 743753       562  ...       1          Unknown              0      1674169892
# 2928636     2344  ...       1       NonEnglish              1      2431409855
#
#                    tweet_id  \
# 42154    807268009312223232
# 1622401  845131935114420230
# 2636047  632530279073214464
# 743753   604638545194708992
# 2928636  671079602773745665
#
#                                                article_url  \
# 42154    http://twitter.com/2620869737/statuses/8072680...
# 1622401  http://twitter.com/1647612534/statuses/8451319...
# 2636047  http://twitter.com/DuraDurnova/statuses/632530...
# 743753   http://twitter.com/J_Cl_k/statuses/60463854519...
# 2928636  http://twitter.com/YanaGreben/statuses/6710796...
#
#                                                 tco1_step1  \
# 42154                                                  NaN
# 1622401  https://twitter.com/kommersant/status/84512102...
# 2636047  http://www.gazeta.ru/social/news/2015/08/15/n_...
# 743753                                                 NaN
# 2928636  https://twitter.com/DemotivatorRUS/status/6710...
#
#                                    tco2_step1 tco3_step1 empty_tweet
# 42154                                     NaN        NaN       False
# 1622401  http://www.kommersant.ru/doc/3250245        NaN       False
# 2636047                                   NaN        NaN       False
# 743753                                    NaN        NaN       False
# 2928636                                   NaN        NaN       False
#
# [5 rows x 22 columns]

# %%
small_df['followers_more_1000'] = small_df['followers'] > 1000
small_df.sample(5)
# Out:
#         external_author_id         author  \
# 2705584         2241496393      EROHOVA_K
# 1170443         2410547836  NIKOLAIZAGAID
# 255384          2611151319   SEATTLE_POST
# 2600178         2536815395     DIMAROSCOE
# 2074064         2882350436    CHRIXMORGAN
#
#                                                    content  \
# 2705584  ХК «Ростов» на домашнем льду выиграл и проигра...
# 1170443  «Рубин» сыграет со «Сьоном» на «Казань-Арене» ...
# 255384   Famous Yellowstone grizzly approaching end  #l...
# 2600178  В рамках плановой боевой подготовки #РВСН расч...
# 2074064  #HowToEscapeADate Make a place for your phone,...
#
#                      region language      publish_date    harvested_date  \
# 2705584       United States  Russian  11/23/2015 22:02  11/23/2015 22:03
# 1170443             Unknown  Russian  11/14/2015 11:55  11/14/2015 11:55
# 255384        United States  English    11/2/2015 4:21    11/2/2015 4:21
# 2600178  Russian Federation  Russian    3/15/2017 6:32    3/15/2017 6:32
# 2074064       United States  English   2/13/2017 14:19   2/13/2017 14:20
#
#          following  followers  updates  ... account_category new_june_2018  \
# 2705584        188        339     3091  ...       NonEnglish             1
# 1170443       1783        248     2694  ...       NonEnglish             1
# 255384        3881      11502    13287  ...         NewsFeed             0
# 2600178        660        102      280  ...       NonEnglish             0
# 2074064      10391      20898    17540  ...     HashtagGamer             0
#
#          alt_external_id            tweet_id  \
# 2705584       2241496393  668912628442505216
# 1170443       2410547836  665498331964141568
# 255384        2611151319  661035448815382528
# 2600178       2536815395  841899984068976641
# 2074064       2882350436  831145884842913792
#
#                                                article_url  \
# 2705584  http://twitter.com/erohova_K/statuses/66891262...
# 1170443  http://twitter.com/NikolaiZagaid/statuses/6654...
# 255384   http://twitter.com/Seattle_Post/statuses/66103...
# 2600178  http://twitter.com/2536815395/statuses/8418999...
# 2074064  http://twitter.com/2882350436/statuses/8311458...
#
#                                                 tco1_step1  \
# 2705584                              http://bit.ly/1Na1UHX
# 1170443                              http://dlvr.it/CkxvDR
# 255384                                                 NaN
# 2600178  https://twitter.com/mod_russia/status/84167807...
# 2074064                                                NaN
#
#                       tco2_step1 tco3_step1 empty_tweet followers_more_1000
# 2705584                      NaN        NaN       False               False
# 1170443                      NaN        NaN       False               False
# 255384                       NaN        NaN       False                True
# 2600178  http://s.mil.ru/2nBbdHx        NaN       False               False
# 2074064                      NaN        NaN       False                True
#
# [5 rows x 23 columns]

# %%
small_df['len_tweet'] = small_df['content'].str.len()
small_df.sample(5)
# Out:
#          external_author_id           author  \
# 1874626          1868496344    BRIANAREGLAND
# 865540   890000000000000000       LAWWAANCTR
# 1825666          1687183549   BLEEPTHEPOLICE
# 2124530  743167000000000000  COVFEFENATIONUS
# 2349492          2878166306   ANDYHASHTAGGER
#
#                                                    content         region  \
# 1874626  Real maple syrup has to be refrigerated after ...  United States
# 865540   #laww Traitor McCain is Now Attacking Trump on...        Unknown
# 1825666  Take notice plainclothes and uniforms a total ...  United States
# 2124530  '@realDonaldTrump @realDonaldTumpr Sorry for h...  United States
# 2349492  Your letter from Hogwarts came today!  #Things...  United States
#
#         language      publish_date    harvested_date  following  followers  \
# 1874626  English  12/24/2016 15:23  12/24/2016 15:23        407        770
# 865540   English    8/9/2017 12:26    8/9/2017 12:26       2977        920
# 1825666  English   12/3/2016 22:05   12/3/2016 22:05       6892      14809
# 2124530  English  11/23/2017 23:30  11/23/2017 23:30        247       2466
# 2349492  English   6/27/2016 13:23   6/27/2016 13:23      19232      22575
#
#          updates  ... new_june_2018     alt_external_id            tweet_id  \
# 1874626     7286  ...             0          1868496344  812680101066395648
# 865540      4648  ...             0  890475284507623424  895259952373272577
# 1825666    14445  ...             0          1687183549  805171189601751046
# 2124530   153416  ...             1  743166519157227520  933840234122326016
# 2349492    11974  ...             1          2878166306  747420183703097345
#
#                                                article_url  \
# 1874626  http://twitter.com/1868496344/statuses/8126801...
# 865540   http://twitter.com/890475284507623424/statuses...
# 1825666  http://twitter.com/1687183549/statuses/8051711...
# 2124530  http://twitter.com/743166519157227520/statuses...
# 2349492  http://twitter.com/AndyHashtagger/statuses/747...
#
#                                                 tco1_step1  \
# 1874626  https://twitter.com/ainteeentrippin/status/812...
# 865540   https://twitter.com/lawwaanCtr/status/89525995...
# 1825666  https://twitter.com/BleepThePolice/status/8051...
# 2124530  https://twitter.com/RepStevenSmith/status/9338...
# 2349492                                                NaN
#
#                     tco2_step1  tco3_step1 empty_tweet followers_more_1000  \
# 1874626                    NaN         NaN       False               False
# 865540   http://ift.tt/2uFxR4w         NaN       False               False
# 1825666                    NaN         NaN       False                True
# 2124530                    NaN         NaN       False                True
# 2349492                    NaN         NaN       False                True
#
#         len_tweet
# 1874626       135
# 865540        126
# 1825666       145
# 2124530        79
# 2349492        65
#
# [5 rows x 24 columns]

# %% [markdown]
# We can also implement more complex transformations, such as those defined in custom functions.
#
# For example, the code below uses a custom function to extract the number of hashtags used in a tweet.

# %%
def num_hashtags(row):
    tweet = row['content']
    try:
        num = tweet.count('#')
        return num
    except AttributeError:
        return 0

small_df['num_hashtags'] = small_df.apply(num_hashtags, axis=1)
small_df
# Out:
#          external_author_id           author  \
# 2076447          2882350436      CHRIXMORGAN
# 945352           2431598206     MARGOBEROEVA
# 476141           3899481526     TODAYINSYRIA
# 2242967          2570250275        AIDEN7757
# 1149978          2530830345     NEWORLEANSON
# ...                     ...              ...
# 847503           2788162002  LARIONOVABOBSPI
# 2672760  892000000000000000        ELIZEESTR
# 1486301          3804542548    NOVOSTIORNBRG
# 140158           2951506251      ROOMOFRUMOR
# 458654           2753146444   TODAYCLEVELAND
#
#                                                    content  \
# 2076447          Oh Allah, There Will Be Blood #ISISAMovie
# 945352   Cloud4Y подтвердил сертификат соответствия тре...
# 476141   #SyrianArmy Forces Hit #IS Centers Hard East o...
# 2242967  '@GhostsofDC Nowadays snowball fight turned to...
# 1149978  New Orleans Saints players salute their father...
# ...                                                    ...
# 847503   Компания "Русский Стандарт Водка" объявляет о ...
# 2672760  RT Vix_LW: Bill: A Media Lynch-Mob is Trying t...
# 1486301  С 1 января Управление Росреестра предоставляет...
# 140158   Alibaba unlikely to be interested in Yahoo's c...
# 458654            #local Fire tears through Cleveland home
#
#                        region language     publish_date   harvested_date  \
# 2076447         United States  English  4/27/2016 15:10  4/27/2016 15:11
# 945352   United Arab Emirates  Russian   5/13/2015 7:12   5/13/2015 7:12
# 476141         United Kingdom  English  5/29/2016 15:05  5/29/2016 15:06
# 2242967         United States  English   2/22/2015 9:57   2/22/2015 9:57
# 1149978         United States  English  6/18/2017 18:38  6/18/2017 18:38
# ...                       ...      ...              ...              ...
# 847503                Unknown  Russian  5/15/2015 11:32  5/15/2015 11:32
# 2672760         United States  English    8/6/2017 6:23    8/6/2017 6:23
# 1486301               Unknown  Russian    2/2/2017 7:21    2/2/2017 7:21
# 140158          United States  English  12/3/2015 12:05  12/3/2015 12:05
# 458654          United States  English  3/17/2015 14:45  3/17/2015 14:45
#
#          following  followers  updates  ...     alt_external_id  \
# 2076447       8894      14526     4694  ...          2882350436
# 945352        1926        359     3389  ...          2431598206
# 476141        7476      19025     5328  ...          3899481526
# 2242967        138         13      319  ...          2570250275
# 1149978       9120      28583    46004  ...          2530830345
# ...            ...        ...      ...  ...                 ...
# 847503         207        207     5429  ...          2788162002
# 2672760       1958        260     3239  ...  891963666828021760
# 1486301        285       3636     4952  ...          3804542548
# 140158        8717      12304    13169  ...          2951506251
# 458654           0          8     1575  ...          2753146444
#
#                    tweet_id  \
# 2076447  725341478021685248
# 945352   598385295030124544
# 476141   736936625809326080
# 2242967  569435720034721792
# 1149978  876509429692289024
# ...                     ...
# 847503   599175427089944577
# 2672760  894081469668306944
# 1486301  827054302292238338
# 140158   672386227115458565
# 458654   577843173478699008
#
#                                                article_url  \
# 2076447  http://twitter.com/ChrixMorgan/statuses/725341...
# 945352   http://twitter.com/margoberoeva/statuses/59838...
# 476141   http://twitter.com/todayinsyria/statuses/73693...
# 2242967  http://twitter.com/Aiden7757/statuses/56943572...
# 1149978  http://twitter.com/2530830345/statuses/8765094...
# ...                                                    ...
# 847503   http://twitter.com/Larionovabobspi/statuses/59...
# 2672760  http://twitter.com/891963666828021760/statuses...
# 1486301  http://twitter.com/3804542548/statuses/8270543...
# 140158   http://twitter.com/RoomOfRumor/statuses/672386...
# 458654   http://twitter.com/TodayCleveland/statuses/577...
#
#                                                 tco1_step1  \
# 2076447                                                NaN
# 945352                               http://bit.ly/1JbSPMs
# 476141   https://twitter.com/todayinsyria/status/736936...
# 2242967                                                NaN
# 1149978  https://twitter.com/NewOrleansON/status/876509...
# ...                                                    ...
# 847503                                                 NaN
# 2672760  http://www.BillOReilly.com/b/Bill:-A-Media-Lyn...
# 1486301  https://twitter.com/NovostiOrnbrg/status/82705...
# 140158                                                 NaN
# 458654                                                 NaN
#
#                                                 tco2_step1 tco3_step1  \
# 2076447                                                NaN        NaN
# 945352                                                 NaN        NaN
# 476141                               http://bit.ly/1Z6MWWA        NaN
# 2242967                                                NaN        NaN
# 1149978  http://www.nola.com/saints/index.ssf/2017/06/n...        NaN
# ...                                                    ...        ...
# 847503                                                 NaN        NaN
# 2672760                                                NaN        NaN
# 1486301                              https://goo.gl/rPxF35        NaN
# 140158                                                 NaN        NaN
# 458654                                                 NaN        NaN
#
#          empty_tweet followers_more_1000 len_tweet num_hashtags
# 2076447        False                True        41            1
# 945352         False               False       110            2
# 476141         False                True       112            3
# 2242967        False               False        58            0
# 1149978        False                True       105            0
# ...              ...                 ...       ...          ...
# 847503         False               False        82            0
# 2672760        False               False        87            0
# 1486301        False                True       119            0
# 140158         False                True        70            1
# 458654         False               False        40            1
#
# [1000 rows x 25 columns]

# %% [markdown]
# In other cases, we will want to use multiple columns to create a new column.
#
# For example, we may want to extract the  calculate the follower-to-following ratio for accounts on Twitter.

# %%
small_df['followers_following_ratio'] = small_df['followers'] / small_df['following']
small_df.sample(10)
# Out:
#          external_author_id          author  \
# 599766           3254273689        FINDDIET
# 2053832  898000000000000000      CHIRRMORRE
# 10014            2260338140  POLITICS_T0DAY
# 2428693          2267612060      ASYAARRIVE
# 2408443          1671936266      ARM_2_ALAN
# 707479   731000000000000000     HAMBURGBOTE
# 2185648          2630842499   DAILYSANDIEGO
# 538635           1964340318         EXQUOTE
# 2615105          1720117201    DONNABRIVERA
# 632191           2260238185      FIONA__ONA
#
#                                                    content         region  \
# 599766   http://t.co/hDdSZgwCue LOL everyone who still ...  United States
# 2053832  EXTREME BIAS! Obama Received 740% More Positiv...        Unknown
# 10014    Европейские атомщики обеспокоились планами Укр...  United States
# 2428693  Букмекеры оценивают победу «Райо Вальекано» на...  United States
# 2408443  Immigrant drivers find new freedom with licens...  United States
# 707479   Prozesse: Prozessbeginn gegen mutmaßlichen PKK...        Unknown
# 2185648  3 men to walk from Cypress to San Diego for ch...  United States
# 538635   http://t.co/v0ctCKXfyg Gotta workout tomorrow ...  United States
# 2615105  Awesome crowd at Philly YRs/RNC/ @PhillyGOP de...  United States
# 632191   ИЗ-ЗА МАССОВЫХ ОТРАВЛЕНИЙ ДЕТЕЙ РЕГИОНЫ ПОПАЛИ...        Unknown
#
#         language      publish_date    harvested_date  following  followers  \
# 599766   English   7/23/2015 16:27   7/23/2015 16:28          3         83
# 2053832  English   10/7/2017 14:04   10/7/2017 14:04       4819       1711
# 10014    Russian     7/5/2016 8:13     7/5/2016 8:13         99        936
# 2428693  Russian  12/20/2015 10:12  12/20/2015 10:12        479        398
# 2408443  English   6/13/2015 14:11   6/13/2015 14:12         66        164
# 707479   Swedish    2/17/2017 5:11    2/17/2017 5:11       1682        355
# 2185648  English   3/31/2016 12:48   3/31/2016 12:48       5249      18348
# 538635   English    7/16/2015 1:45    7/16/2015 1:45          2        290
# 2615105  English   1/29/2016 12:47   1/29/2016 12:47        183        397
# 632191   Russian  12/25/2015 13:38  12/25/2015 13:38        126        258
#
#          updates  ...            tweet_id  \
# 599766      8638  ...  624254643938291712
# 2053832     1947  ...  916665521004797952
# 10014      16688  ...  750241111059394560
# 2428693     5544  ...  678518292814897152
# 2408443     9254  ...  609724896218775552
# 707479      1788  ...  832457346903191552
# 2185648    13385  ...  715521051392774145
# 538635     13603  ...  621495723368976384
# 2615105     1546  ...  693052928848822274
# 632191      3394  ...  680382112206315520
#
#                                                article_url  \
# 599766   http://twitter.com/FindDiet/statuses/624254643...
# 2053832  http://twitter.com/898467846774300672/statuses...
# 10014    http://twitter.com/politics_t0day/statuses/750...
# 2428693  http://twitter.com/AsyaArrive/statuses/6785182...
# 2408443  http://twitter.com/Arm_2_Alan/statuses/6097248...
# 707479   http://twitter.com/731021916568424449/statuses...
# 2185648  http://twitter.com/DailySanDiego/statuses/7155...
# 538635   http://twitter.com/ExQuote/statuses/6214957233...
# 2615105  http://twitter.com/DonnaBRivera/statuses/69305...
# 632191   http://twitter.com/Fiona__Ona/statuses/6803821...
#
#                                                 tco1_step1  \
# 599766   https://twitter.com/safety/unsafe_link_warning...
# 2053832                              http://ift.tt/2xZNB8u
# 10014    https://twitter.com/politics_t0day/status/7502...
# 2428693                              http://dlvr.it/D3YPQ4
# 2408443                                http://dld.bz/dG64Q
# 707479   http://www.zeit.de/hamburg/aktuell/2017-02/17/...
# 2185648  https://twitter.com/DailySanDiego/status/71552...
# 538635   https://twitter.com/safety/unsafe_link_warning...
# 2615105  https://twitter.com/DarinB22/status/6928909354...
# 632191   https://twitter.com/RomaKryglov/status/6803819...
#
#                                                 tco2_step1  tco3_step1  \
# 599766                                                 NaN         NaN
# 2053832                                                NaN         NaN
# 10014                  https://vk.com/wall-62675857_225283         NaN
# 2428693                                                NaN         NaN
# 2408443                                                NaN         NaN
# 707479                                                 NaN         NaN
# 2185648  http://www.click2houston.com/news/3-men-to-wal...         NaN
# 538635                                                 NaN         NaN
# 2615105                                                NaN         NaN
# 632191   http://mirnov.ru/-na-raspredelenie/iz-za-masso...         NaN
#
#         empty_tweet  followers_more_1000 len_tweet num_hashtags  \
# 599766        False                False       111            0
# 2053832       False                 True        97            0
# 10014         False                False       138            1
# 2428693       False                False        99            0
# 2408443       False                False        92            1
# 707479        False                False        92            0
# 2185648       False                 True       100            0
# 538635        False                False       137            0
# 2615105       False                False       113            2
# 632191        False                False       115            0
#
#         followers_following_ratio
# 599766                  27.666667
# 2053832                  0.355053
# 10014                    9.454545
# 2428693                  0.830898
# 2408443                  2.484848
# 707479                   0.211058
# 2185648                  3.495523
# 538635                 145.000000
# 2615105                  2.169399
# 632191                   2.047619
#
# [10 rows x 26 columns]

# %%
def follow_following(row, default_return=0):
    followers = row['followers']
    following = row['following']
    try:
        return followers / following
    except:
        return default_return
    
small_df['following_followers_2'] = small_df.apply(follow_following, axis=1)
small_df
# Out:
#          external_author_id           author  \
# 2076447          2882350436      CHRIXMORGAN
# 945352           2431598206     MARGOBEROEVA
# 476141           3899481526     TODAYINSYRIA
# 2242967          2570250275        AIDEN7757
# 1149978          2530830345     NEWORLEANSON
# ...                     ...              ...
# 847503           2788162002  LARIONOVABOBSPI
# 2672760  892000000000000000        ELIZEESTR
# 1486301          3804542548    NOVOSTIORNBRG
# 140158           2951506251      ROOMOFRUMOR
# 458654           2753146444   TODAYCLEVELAND
#
#                                                    content  \
# 2076447          Oh Allah, There Will Be Blood #ISISAMovie
# 945352   Cloud4Y подтвердил сертификат соответствия тре...
# 476141   #SyrianArmy Forces Hit #IS Centers Hard East o...
# 2242967  '@GhostsofDC Nowadays snowball fight turned to...
# 1149978  New Orleans Saints players salute their father...
# ...                                                    ...
# 847503   Компания "Русский Стандарт Водка" объявляет о ...
# 2672760  RT Vix_LW: Bill: A Media Lynch-Mob is Trying t...
# 1486301  С 1 января Управление Росреестра предоставляет...
# 140158   Alibaba unlikely to be interested in Yahoo's c...
# 458654            #local Fire tears through Cleveland home
#
#                        region language     publish_date   harvested_date  \
# 2076447         United States  English  4/27/2016 15:10  4/27/2016 15:11
# 945352   United Arab Emirates  Russian   5/13/2015 7:12   5/13/2015 7:12
# 476141         United Kingdom  English  5/29/2016 15:05  5/29/2016 15:06
# 2242967         United States  English   2/22/2015 9:57   2/22/2015 9:57
# 1149978         United States  English  6/18/2017 18:38  6/18/2017 18:38
# ...                       ...      ...              ...              ...
# 847503                Unknown  Russian  5/15/2015 11:32  5/15/2015 11:32
# 2672760         United States  English    8/6/2017 6:23    8/6/2017 6:23
# 1486301               Unknown  Russian    2/2/2017 7:21    2/2/2017 7:21
# 140158          United States  English  12/3/2015 12:05  12/3/2015 12:05
# 458654          United States  English  3/17/2015 14:45  3/17/2015 14:45
#
#          following  followers  updates  ...  \
# 2076447       8894      14526     4694  ...
# 945352        1926        359     3389  ...
# 476141        7476      19025     5328  ...
# 2242967        138         13      319  ...
# 1149978       9120      28583    46004  ...
# ...            ...        ...      ...  ...
# 847503         207        207     5429  ...
# 2672760       1958        260     3239  ...
# 1486301        285       3636     4952  ...
# 140158        8717      12304    13169  ...
# 458654           0          8     1575  ...
#
#                                                article_url  \
# 2076447  http://twitter.com/ChrixMorgan/statuses/725341...
# 945352   http://twitter.com/margoberoeva/statuses/59838...
# 476141   http://twitter.com/todayinsyria/statuses/73693...
# 2242967  http://twitter.com/Aiden7757/statuses/56943572...
# 1149978  http://twitter.com/2530830345/statuses/8765094...
# ...                                                    ...
# 847503   http://twitter.com/Larionovabobspi/statuses/59...
# 2672760  http://twitter.com/891963666828021760/statuses...
# 1486301  http://twitter.com/3804542548/statuses/8270543...
# 140158   http://twitter.com/RoomOfRumor/statuses/672386...
# 458654   http://twitter.com/TodayCleveland/statuses/577...
#
#                                                 tco1_step1  \
# 2076447                                                NaN
# 945352                               http://bit.ly/1JbSPMs
# 476141   https://twitter.com/todayinsyria/status/736936...
# 2242967                                                NaN
# 1149978  https://twitter.com/NewOrleansON/status/876509...
# ...                                                    ...
# 847503                                                 NaN
# 2672760  http://www.BillOReilly.com/b/Bill:-A-Media-Lyn...
# 1486301  https://twitter.com/NovostiOrnbrg/status/82705...
# 140158                                                 NaN
# 458654                                                 NaN
#
#                                                 tco2_step1 tco3_step1  \
# 2076447                                                NaN        NaN
# 945352                                                 NaN        NaN
# 476141                               http://bit.ly/1Z6MWWA        NaN
# 2242967                                                NaN        NaN
# 1149978  http://www.nola.com/saints/index.ssf/2017/06/n...        NaN
# ...                                                    ...        ...
# 847503                                                 NaN        NaN
# 2672760                                                NaN        NaN
# 1486301                              https://goo.gl/rPxF35        NaN
# 140158                                                 NaN        NaN
# 458654                                                 NaN        NaN
#
#          empty_tweet followers_more_1000  len_tweet num_hashtags  \
# 2076447        False                True         41            1
# 945352         False               False        110            2
# 476141         False                True        112            3
# 2242967        False               False         58            0
# 1149978        False                True        105            0
# ...              ...                 ...        ...          ...
# 847503         False               False         82            0
# 2672760        False               False         87            0
# 1486301        False                True        119            0
# 140158         False                True         70            1
# 458654         False               False         40            1
#
#         followers_following_ratio following_followers_2
# 2076447                  1.633236              1.633236
# 945352                   0.186397              0.186397
# 476141                   2.544810              2.544810
# 2242967                  0.094203              0.094203
# 1149978                  3.134101              3.134101
# ...                           ...                   ...
# 847503                   1.000000              1.000000
# 2672760                  0.132789              0.132789
# 1486301                 12.757895             12.757895
# 140158                   1.411495              1.411495
# 458654                        inf              0.000000
#
# [1000 rows x 27 columns]

# %% [markdown]
# Once again, we can use a custom function to transform multiple columns to create one new column.
#
# In the cell below, use a custom function and the `apply()` method to create a new column called `more_followers` from the `followers` and `following` columns. This column should be `True` if an account has more followers than following, and `False` otherwise.

# %%
# Your Answer Here

# %% [markdown]
# Checkout the results of our transformations in the `DataFrame` below.

# %%
small_df.sample(10)
# Out:
#         external_author_id           author  \
# 87582           2616344667     AMANDAVGREEN
# 354             2495567768     DAILYSANFRAN
# 96980           2547141851  CHICAGODAILYNEW
# 3550            2742482932        CASCASEYP
# 59251           1877492857   CHESPLAYSCHESS
# 41208           1676377446       CHADSLOYER
# 238909  749926000000000000        MARKBERER
# 57110   725000000000000000       BERLINBOTE
# 92573           2543205364  OLGAMOROZOVAMSK
# 95112           1715190968    ONEMIGHTYFISH
#
#                                                   content          region  \
# 87582                  Forrest Hump #DickFlicks @midnight   United States
# 354     PHOTOS: Women's March in Oakland, San Francisc...   United States
# 96980   Brewers Beat MLB ERA Leader Hendricks And Cubs...   United States
# 3550      Rumble in the Jungle Book #AddCartoonsToHistory  United Kingdom
# 59251   Buckled lane closes major Atlanta highway http...   United States
# 41208   #BlackLivesMatter #JusticeForMarioWoods #Mario...   United States
# 238909  SZ-Democracy-Lab: Das bewegt Deutschland https...         Unknown
# 57110   NPD-Funktionär steht wegen Volksverhetzung vor...         Unknown
# 92573   «Амкар» объявил о подписании контракта с напад...         Unknown
# 95112   Uncle Ruckus spawned coons https://t.co/CNfWQo...   United States
#
#        language     publish_date   harvested_date  following  followers  \
# 87582   English   2/28/2017 8:28   2/28/2017 9:00       6666       6626
# 354     English   1/22/2017 3:29   1/22/2017 3:29       4570      16776
# 96980   English  9/18/2016 23:57  9/18/2016 23:58       7114      19484
# 3550    English   8/2/2017 11:34   8/2/2017 11:35       4356       5265
# 59251   English  4/17/2017 22:32  4/17/2017 22:32       1017       1490
# 41208   English  6/17/2016 13:18  6/17/2016 13:18        824        443
# 238909   German   7/13/2017 8:50   7/13/2017 8:51       1213        308
# 57110    German   1/24/2017 2:06   1/24/2017 2:06       1025        115
# 92573   Russian  7/16/2015 10:52  7/16/2015 10:52       1691        298
# 95112   English  10/21/2016 2:16  10/21/2016 2:16        831        699
#
#         updates  ... new_june_2018     alt_external_id            tweet_id  \
# 87582      6446  ...             0          2616344667  836493333501399040
# 354       35799  ...             0          2495567768  823009623322095617
# 96980     37433  ...             0          2547141851  777657945026768896
# 3550       4459  ...             0          2742482932  892710291959554048
# 59251     19368  ...             0          1877492857  854100301623644160
# 41208      1151  ...             0          1676377446  743794904334204928
# 238909      413  ...             1  749926493409648640  885421241972252672
# 57110     11174  ...             0  725305686989656064  823713560341737473
# 92573      1639  ...             1          2543205364  621633441352826880
# 95112      1690  ...             0          1715190968  789289139564863488
#
#                                               article_url  \
# 87582   http://twitter.com/2616344667/statuses/8364933...
# 354     http://twitter.com/2495567768/statuses/8230096...
# 96980   http://twitter.com/ChicagoDailyNew/statuses/77...
# 3550    http://twitter.com/2742482932/statuses/8927102...
# 59251   http://twitter.com/1877492857/statuses/8541003...
# 41208   http://twitter.com/ChadSloyer/statuses/7437949...
# 238909  http://twitter.com/749926493409648640/statuses...
# 57110   http://twitter.com/725305686989656064/statuses...
# 92573   http://twitter.com/olgamorozovamsk/statuses/62...
# 95112   http://twitter.com/OneMightyFish/statuses/7892...
#
#                                                tco1_step1  \
# 87582                                                 NaN
# 354     https://twitter.com/DailySanFran/status/823009...
# 96980                            http://cbsloc.al/2cIKJQs
# 3550                                                  NaN
# 59251   https://twitter.com/dn_nation_world/status/854...
# 41208                                                 NaN
# 238909                             http://sz.de/1.3582821
# 57110   https://twitter.com/BerlinBote/status/82371356...
# 92573                               http://dlvr.it/BXm09B
# 95112   https://twitter.com/mikie_v/status/78895267728...
#
#                                                tco2_step1  tco3_step1  \
# 87582                                                 NaN         NaN
# 354     http://abc7news.com/politics/photos-womens-mar...         NaN
# 96980                                                 NaN         NaN
# 3550                                                  NaN         NaN
# 59251                             http://detne.ws/2punIGJ         NaN
# 41208                                                 NaN         NaN
# 238909                                                NaN         NaN
# 57110   http://www.berliner-zeitung.de/berlin/npd-funk...         NaN
# 92573                                                 NaN         NaN
# 95112                                                 NaN         NaN
#
#        empty_tweet num_hashtags followers_following_ratio
# 87582        False            1                  0.993999
# 354          False            0                  3.670897
# 96980        False            0                  2.738825
# 3550         False            1                  1.208678
# 59251        False            0                  1.465093
# 41208        False            6                  0.537621
# 238909       False            0                  0.253916
# 57110        False            0                  0.112195
# 92573        False            0                  0.176227
# 95112        False            0                  0.841155
#
# [10 rows x 24 columns]

# %% [markdown]
# ### <i class="fa fa-graduation-cap"></i> Avoiding Slow Pandas [<i class="fa fa-forward"></i>](#skip_slow)
#
# From [pandas](https://pandas.pydata.org/):
# >pandas is a **fast**, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# This is all true, with a pretty large caveat. Pandas is fast (and generally efficient), if you avoid some of the common pitfalls. Unfortunately, these traps are easy to fall for and many pandas users (even senior data scientists) don't know they might be slowing their code down 10-1000x. These people will often be hesitant to use pandas on large datasets and may dissuade others from using the library.
#
# However, by understanding a little about what is going on in the backend, we can avoid the worst of the problems and write relatively fast pandas code.
#
# #### How are DataFrames stored?
#
# DataFrames are really just a collection of `Series`, with each column corresponding to its own `Series`. In a `Series`, each item is stored one after the other in memory. This means that the entire column is stored within a single range of memory.
#
# However, the multiple Series (columns) that make a DataFrame can be stored anywhere in memory and are often not stored side-by-side.
#
# We can think of this like a grocery list for sandwiches. Lets imagine that each kind of sandwich we make is composed of 1 type of bread, 1 type of  meat and 1 type of vegetable. We could arrange our grocery list into a table like this:
#
# | sandwich_id | bread_type | meat_type  | vegetable_type |
# |-------------|------------|------------|----------------|
# | 0           | sourdough  | ham        | lettuce        |
# | 1           | baguette   | turkey     | tomato         |
# | 2           | rye        | roast beef | onion          |
#
# We buy all of our bread products from a bakery, meat from a deli, and vegetables from a grocer. The result is that to get everything in a column, you can go to one location (e.g. bakery for bread_type). But to get everything from a row you will have to visit all three locations.
#
# This means it is really fast to access an entire column, but really slow to access an entire row. Lets check it out!

# %%
print('Column\n------')
# %timeit col = small_df['following']

print('Row\n------')
# %timeit row = small_df.iloc[12]
# Out:
# Column
# ------
# 1.4 µs ± 10.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# Row
# ------
# 122 µs ± 3.76 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# In this case, there was more than a 60x difference in speed!
#
# Understanding how `DataFrames` are stored in memory can help us understand why different approaches to `DataFrame` transformations vary so much in speed. Ideally, we can use this information to write efficient pandas code.

# %% [markdown]
# #### For Loops & `iterrows`
# Perhaps one of the most obvious ways to approach a transformation is to go row-by-row through the dataframe, doing the necessary transformations one at a time. A simple way to do this is using a `for` loop.

# %%
# %%timeit
diff_followers = []
for i in small_df.index:
    row = small_df.loc[i]
    diff = row['followers'] - row['following']
    diff_followers.append(diff)
# Out:
# 184 ms ± 344 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# A second method we can use to add our new column is using the `iterrows()` method ([docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html#pandas.DataFrame.iterrows)). This is a built-in pandas method, which has been implemented to iterate over the rows in a  DataFrame.
#
# This method creates a [generator object](https://wiki.python.org/moin/Generators), a special Python object, which we can use a for loop to iterate over.

# %%
# %%timeit
diff_followers = []
for idx, row in small_df.iterrows():
    diff = row['followers'] - row['following']
    diff_followers.append(diff)
# Out:
# 97.7 ms ± 3.61 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# While this is definitely faster than the basic `for` loop approach, I'll tell you know that it is still really slow! In fact, the underlying reason why both of these approaches are so slow is the same.
#
# Both approaches use a `for` loop to go row-by-row through the DataFrame. Gathering the data for that _row_ as its needed.
#
# In our sandwich example, this is the equivalent of buying ingredients for sandwich 1, then buying ingredients for sandwich 2, etc. This results in visiting each shop (bakery, deli, grocer) once for every sandwich recipe!
#
# The same thing is happening in pandas. To iterate over the rows using a `for` loop we retreive all values for row 1, then all values for row 2, etc.
#
# This is incredibly inefficient (imagine the funny looks you'd get on your 3rd visit to the bakery)! In fact, I would venture to say that **you should never use for loops when working with pandas `DataFrames`**. There might be cases when I'm wrong, but there is almost always a better approach than `for` loops.

# %% [markdown]
# ## The `apply()` Method
# A third approach we can use is the `apply()` method ([docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html#pandas.DataFrame.apply)). This built-in pandas method applies a specific function across some axis &mdash; either rows or columns (More on this [later](#axes)). In our case, we want to apply a function along the column axis, applying the function to each row.
#
# To use `apply()`, you have to define the function you want to apply to each row. This function needs to take in a row, apply the function, and return some value. For our case, we'll define an `difference()` function.

# %%
# %%timeit

def difference(row):
    return row['followers'] - row['following']

diff_followers = small_df.apply(difference, axis=1)
# Out:
# 20.4 ms ± 41.5 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# While this is significantly faster than the previous to approaches, it is still relatively slow because it continues to go row-by-row through the Dataframe.
#
# Since `apply()` is used for a specific purpose, pandas is able to make assumptions and include optmizations the general approaches (e.g. `for` loops) don't have access to.
#
# For example, `apply()` checks to see if your function is compatible with its "fast" mode ([docs](https://github.com/pandas-dev/pandas/blob/v0.25.3/pandas/core/frame.py#L6737-L6928)). As well, it offloads some of the work to C (a low-level language known for speed), only performing the functions themselves in Python.
#
# Typically, **I almost always avoid using `apply()`**. Although, it does make for readable code.

# %% [markdown]
# #### `zip()` and Iterate
# A fourth approach is to use Python's built-in `zip()` function ([docs](https://docs.python.org/3.3/library/functions.html#zip)). This function takes in a group of iterators (lists, dictionaries, tuples, etc) and creates a new iterator where the i-th element in the iterator will be a tuple containing the i-th elements from each of the original iterators.

# %%
l1 = [1, 2, 3]
l2 = ['a', 'b', 'c']
z = zip(l1, l2)
list(z)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %% [markdown]
# This function is useful for many different purposes. For our case, we will
# 1. Select columns needed for transformation
# 2. Zip these columns together
# 3. Iterate over the zipped object to retrieve pairs one at a time, applying a function to the pairs and storing the result in a list which will later become our new column

# %%
# %%timeit
diff_followers = []
for followers, following in zip(small_df['followers'], small_df['following']):
    diff = followers - following
    diff_followers.append(diff)
# Out:
# 217 µs ± 4.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# This method offers a great improvement over our last method (~120x faster). This is the first method that avoids going row-by-row through the `DataFrame`.
#
# Instead of performing many costly read operations (#rows x #columns), this method reads each column only once. The resulting data is stored temporarily in fast memory, where it can be accessed at little cost when it is needed for calculations.
#
# **This is the method I typically use for complicated transformations that involve non-standard operations.**

# %% [markdown]
# ## Vectorized Functions
# Depending on the transformation, we may be able to use a vectorized function. These functions operate on entire Series, rather individual values (aka vector functions).
#
# There are many built-in vectorized functions, such as `-` (shown below), `add()`, `between()`, and `shift`. You can also build your own vectorized function as a combination of these built-in methods.

# %%
# %%timeit
diff_followers = small_df['followers'] - small_df['following']
# Out:
# 157 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# As with the `zip()` approach, vectorized functions avoid costly row-by-row reads. Vectorized functions also take advantage of pre-compiled code written in lower-level (and faster) languages such as C.
#
# We can go one step further and convert pandas `Series` into NumPy arrays, applying the same vectorized functions to obtain our transformation.

# %%
# %%timeit
diff_followers = np.array(small_df['followers']) - np.array(small_df['following'])
# Out:
# 21.5 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# By converting the pandas `Series` to NumPy arrays this method removes the overhead incurred by Pandas additional functionality.
#
# ## Going Futher
# For cases when even these options aren't fast enough, you can implement more advanced techniques to enhance performance. The improvements offered by these advanced techniques differ based on the problem. For example, some techniques use functions and methods optimized for boolean comparisons (e.g. great than) but offer little improvements when working with other functions like addition.
#
# Some approaches to checkout include:
# * Using [NumExpr](https://pypi.org/project/numexpr/2.6.1/) for extra fast numerical expressions
# * Rewriting functions in [Cython](https://cython.org/)
# * Using [Numba](https://numba.pydata.org/) to convert Python code to fast machine code.
#
# #### Key Points
# While differences in speed are hard (if not impossible) to notice for small datasets, it can become hugely consequential when working with large datasets or performing complex calculations.
#
# We have to remember optimizing code should not be placed at the expense of functionality. Often its best to get something that works before going back and finding the optimal solution. However, I hope that by introducing a couple of "Do's & Don'ts" your first insticts can help you avoid some of the easiest traps.
#
# 1. Never directly iterate over the rows in a DataFrame. Avoid anything that goes row-by-row.
# 2. Working with NumPy arrays will be faster than pandas Series
# 3. DataFrame data is stored based on columns, not rows. This means its much faster to access a column than a row.

# %% [markdown]
# <a id='skip_slow'></a><a id='agg'></a>
# #  <i class="fa fa-location-arrow"></i> AGGREGATION AND GROUPED OPERATIONS
#
# Some of the most common tasks in any given data analysis project involve some sort of aggregation or grouped operation. For example, we might want to compute and compare descriptive statistics for observations that take different values on a categorical variable. Let's see how to do that, and other grouped operations, with `pandas`.
#
# In brief, the `group_by()` method splits the `dataframe` into groups based on the values of a given variable. We can then perform operations on the resulting groups, such as computing descriptive statistics.

# %%
grouped = df.groupby('account_category')
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# The code above returns a grouped object that we can work with. Let's say we want to pull out a specific group. We can use the `get_group()` method to pull a group from the grouped object. (Note that the `.get_group()` code below is equivalent to `df[df['account_type'] == 'RightTroll']`.)

# %%
right_troll_group = grouped.get_group('RightTroll')
right_troll_group.head(10)
# Out:
#       external_author_id      author  \
# 17628         2912754262  POLITWEECS
# 17629         2912754262  POLITWEECS
# 17630         2912754262  POLITWEECS
# 17631         2912754262  POLITWEECS
# 17632         2912754262  POLITWEECS
# 17633         2912754262  POLITWEECS
# 17634         2912754262  POLITWEECS
# 17635         2912754262  POLITWEECS
# 17636         2912754262  POLITWEECS
# 17637         2912754262  POLITWEECS
#
#                                                  content         region  \
# 17628  It's another beautiful but breezy day! http://...  United States
# 17629  First Michiana business to publicly deny same-...  United States
# 17630  Obama for Prezident in 2016 #BadPrankIn5Words ...  United States
# 17631  The U.S. and #Cuba have held their HIGHest-lev...  United States
# 17632  Fox is about to end #TheSimpsons seasonal DVD ...  United States
# 17633  Police horse named Jacob with a prestigious jo...  United States
# 17634  This is an amazing Sun Cruise Resort hotel of ...  United States
# 17635  Being #fat in middle age reduces risk of devel...  United States
# 17636  #Obama approval rating among #Jews has gone fr...  United States
# 17637  You can buy about 2000 #pizza s instead of gol...  United States
#
#        language     publish_date   harvested_date  following  followers  \
# 17628   English   4/1/2015 15:30   4/1/2015 15:30        712        188
# 17629   English   4/1/2015 15:33   4/1/2015 15:33        712        188
# 17630  Croatian   4/1/2015 16:15   4/1/2015 16:16        712        188
# 17631   English  4/10/2015 10:00  4/10/2015 10:00        589       5543
# 17632   English  4/10/2015 10:07  4/10/2015 10:07        589       5543
# 17633   English  4/10/2015 11:24  4/10/2015 11:24        589       5543
# 17634   English  4/10/2015 12:03  4/10/2015 12:03        589       5543
# 17635   English  4/10/2015 13:39  4/10/2015 13:39        589       5541
# 17636   English  4/10/2015 15:24  4/10/2015 15:24        589       5536
# 17637   English  4/10/2015 16:24  4/10/2015 16:24        589       5535
#
#        updates  ... retweet account_category  new_june_2018 alt_external_id  \
# 17628        1  ...       1       RightTroll              0      2912754262
# 17629        2  ...       0       RightTroll              0      2912754262
# 17630        3  ...       0       RightTroll              0      2912754262
# 17631       62  ...       0       RightTroll              0      2912754262
# 17632       63  ...       0       RightTroll              0      2912754262
# 17633       64  ...       0       RightTroll              0      2912754262
# 17634       65  ...       0       RightTroll              0      2912754262
# 17635       66  ...       0       RightTroll              0      2912754262
# 17636       67  ...       0       RightTroll              0      2912754262
# 17637       68  ...       0       RightTroll              0      2912754262
#
#                  tweet_id                                        article_url  \
# 17628  583290244151140352  http://twitter.com/Politweecs/statuses/5832902...
# 17629  583291010551169025  http://twitter.com/Politweecs/statuses/5832910...
# 17630  583301633494249474  http://twitter.com/Politweecs/statuses/5833016...
# 17631  586468665920360448  http://twitter.com/Politweecs/statuses/5864686...
# 17632  586470580724957185  http://twitter.com/Politweecs/statuses/5864705...
# 17633  586489845469483008  http://twitter.com/Politweecs/statuses/5864898...
# 17634  586499757113118721  http://twitter.com/Politweecs/statuses/5864997...
# 17635  586523818929164290  http://twitter.com/Politweecs/statuses/5865238...
# 17636  586550375068536832  http://twitter.com/Politweecs/statuses/5865503...
# 17637  586565440979144704  http://twitter.com/Politweecs/statuses/5865654...
#
#                                               tco1_step1 tco2_step1  \
# 17628  https://twitter.com/JesseHawilaKCTV/status/583...        NaN
# 17629                                                NaN        NaN
# 17630  https://twitter.com/Politweecs/status/58330163...        NaN
# 17631  https://twitter.com/Politweecs/status/58646866...        NaN
# 17632                                                NaN        NaN
# 17633  https://twitter.com/Politweecs/status/58648984...        NaN
# 17634  https://twitter.com/Politweecs/status/58649975...        NaN
# 17635  https://twitter.com/Politweecs/status/58652381...        NaN
# 17636  https://twitter.com/Politweecs/status/58655037...        NaN
# 17637                                                NaN        NaN
#
#       tco3_step1 used_to_be_the_index
# 17628        NaN                17628
# 17629        NaN                17629
# 17630        NaN                17630
# 17631        NaN                17631
# 17632        NaN                17632
# 17633        NaN                17633
# 17634        NaN                17634
# 17635        NaN                17635
# 17636        NaN                17636
# 17637        NaN                17637
#
# [10 rows x 22 columns]

# %% [markdown]
# As previously mentioned, sometimes we want to compute some value for a group within the dataset. We can do this by specifying the grouped object, the `Series` we want to perform an operation on, and finally the operation we want to perform. A full list of operations available when working with `Series` can be found in the [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html).

# %%
grouped['followers'].median()
# Out:
# account_category
# Commercial        273
# Fearmonger         48
# HashtagGamer     2480
# LeftTroll         836
# NewsFeed        14722
# NonEnglish        503
# RightTroll       1437
# Unknown           205
# Name: followers, dtype: int64

# %%
grouped['following'].median()
# Out:
# account_category
# Commercial         3
# Fearmonger        65
# HashtagGamer    2613
# LeftTroll        796
# NewsFeed        7089
# NonEnglish       434
# RightTroll      1864
# Unknown          567
# Name: following, dtype: int64

# %% [markdown]
# There are many things you can do here, such as comparing the ratio of followers to following.

# %%
grouped['followers'].median() / grouped['following'].median()
# Out:
# account_category
# Commercial      91.000000
# Fearmonger       0.738462
# HashtagGamer     0.949101
# LeftTroll        1.050251
# NewsFeed         2.076739
# NonEnglish       1.158986
# RightTroll       0.770923
# Unknown          0.361552
# dtype: float64

# %% [markdown]
# We can also perform some operations on the grouped object itself, such as computing the number of observations in each group, which in this case is equal to the number of tweets sent by accounts in each category.

# %%
grouped.size().sort_values(ascending=False)
# Out:
# account_category
# NonEnglish      820803
# RightTroll      711668
# NewsFeed        598226
# LeftTroll       427141
# HashtagGamer    241786
# Commercial      121904
# Unknown          13539
# Fearmonger       11140
# dtype: int64

# %% [markdown]
# It is also possible to group by multiple variables, such as `account_category` and `language`, and then perform an operation on the groups, such as compute the median number of followers.

# %%
cat_lang = df.groupby(['account_category', 'language'], as_index=False)['followers'].median()
cat_lang.sample(30)
# Out:
#     account_category            language  followers
# 68        Fearmonger           Icelandic       48.0
# 11        Commercial     Farsi (Persian)      393.0
# 338          Unknown              Pushto       54.0
# 192         NewsFeed           Icelandic    12299.0
# 120     HashtagGamer             Spanish     2039.5
# 188         NewsFeed             Finnish    19035.5
# 305       RightTroll           Slovenian     2082.0
# 239       NonEnglish            Japanese      107.0
# 1         Commercial              Arabic      387.0
# 202         NewsFeed              Polish    13807.5
# 2         Commercial             Bengali      353.0
# 55        Commercial          Vietnamese      294.0
# 166        LeftTroll           Slovenian      925.0
# 268       RightTroll             Bengali        1.0
# 313       RightTroll                Urdu     1472.0
# 15        Commercial               Greek      518.0
# 95      HashtagGamer             Finnish     2018.0
# 260       NonEnglish  Tagalog (Filipino)      495.5
# 185         NewsFeed             English    14725.0
# 245       NonEnglish          Macedonian      406.0
# 180         NewsFeed             Catalan    13131.5
# 27        Commercial  LANGUAGE UNDEFINED      851.0
# 256       NonEnglish           Slovenian      106.0
# 143        LeftTroll              German      843.0
# 193         NewsFeed          Indonesian    12290.0
# 99      HashtagGamer           Hungarian     2745.0
# 223       NonEnglish              Danish      978.0
# 28        Commercial             Latvian      434.0
# 332          Unknown            Japanese       30.0
# 231       NonEnglish               Greek      338.5

# %% [markdown]
# Depending on what you are doing, the result of a grouped analysis like this could be a `Series` or a `DataFrame`.
#
# Finally, we can perform *multiple* operations on a grouped object by using the `agg()` method ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html)). The `agg()` method will apply one or more aggregate functions to a grouped object, returning the results of each.
#
# To specify which operations `agg()` will apply, a list of functions or string function names is provided. Each function must accept a `Series` or `DataFrame` as input (depending on what type the grouped object is) or work when passed to the `apply()` method.
#
# We can re-implement the median calculation from above using the `agg()` function.

# %%
grouped['followers'].agg([np.median])
# Out:
#                   median
# account_category
# Commercial           273
# Fearmonger            48
# HashtagGamer        2480
# LeftTroll            836
# NewsFeed           14722
# NonEnglish           503
# RightTroll          1437
# Unknown              205

# %% [markdown]
# We can specify additional functions by adding to the list provided to `agg()`. Notice that we can use a function or a string function name when specifying which operations to apply.

# %%
grouped['followers'].agg([min, np.median, 'max', 'count'])
# Out:
#                   min  median     max   count
# account_category
# Commercial          0     273     858  121904
# Fearmonger          0      48     120   11140
# HashtagGamer        0    2480   24663  241786
# LeftTroll           0     836   56725  427141
# NewsFeed            0   14722   62088  598226
# NonEnglish         -1     503  251276  820803
# RightTroll          0    1437  145244  711668
# Unknown             0     205    6343   13539

# %% [markdown]
# We can even define our own function for `agg()` to use.

# %%
def count_greater_than_0(series):
    gt_0 = series[series > 0]
    return len(gt_0)

grouped['followers'].agg(['min', np.median, 'max', 'count', count_greater_than_0])
# Out:
#                   min  median     max   count  count_greater_than_0
# account_category
# Commercial          0     273     858  121904                121704
# Fearmonger          0      48     120   11140                 10898
# HashtagGamer        0    2480   24663  241786                240713
# LeftTroll           0     836   56725  427141                426891
# NewsFeed            0   14722   62088  598226                597888
# NonEnglish         -1     503  251276  820803                817637
# RightTroll          0    1437  145244  711668                703651
# Unknown             0     205    6343   13539                 12997

# %% [markdown]
# <a id='axes'></a>
# ### <i class="fa fa-graduation-cap"></i> Background Knowledge &mdash; Axes [<i class="fa fa-forward"></i>](#skip_axes)
#
# Once again, feel free to skip this section.
#
# If you took a chance to delve into the documentation for any of the aggregation functions, you may have noticed an optional parameter called `axis`. The description of this parameter usually says something like:
#
# > **axis : {0 or ‘index’, 1 or ‘columns’}, default 0**
# If 0 or ‘index’: apply function to each column. If 1 or ‘columns’: apply function to each row.
#
# In other words, `axis=0` is going to operate over the columns of the dataframe and `axis=1` will operate over the rows in the dataframe.
#
# If we are doing tasks related to columns, such as calculating the median value of a column or sorting by a column, we will want to set `axis=0`.
#
# If we are doing tasks related to rows, such as dropping rows with missing values or using the `apply()` method to create a new column, we will want to set `axis=1`.
#
# As a bit of foreshadowing, operating over rows is generally very slow. We will touch on it later on during [a later]() Background Knowledge section.

# %% [markdown]
# <a id='skip_axes'></a><a id='sort'></a>
# #  <i class="fa fa-location-arrow"></i> SORTING AND RANKING
#
# Sorting and ranking observations based on some criteria is a common data analysis task. For example, we might want to know which accounts in our dataset have the most followers.
#
# First, I will create a new `DataFrame` with some extra follower information for each account category & language group.

# %%
new_cat_lang = df.groupby(['account_category', 'language'], as_index=False)['followers'].agg([min, np.median, max]).reset_index()
new_cat_lang.columns = ['account_category', 'language', 'followers_min', 'followers_median', 'followers_max']
new_cat_lang.sample(10)
# Out:
#     account_category         language  followers_min  followers_median  \
# 11        Commercial  Farsi (Persian)            116             393.0
# 56        Fearmonger         Albanian             53              53.0
# 221       NonEnglish         Croatian              0             151.0
# 9         Commercial          English              0             262.0
# 132        LeftTroll        Bulgarian             85             365.0
# 301       RightTroll          Russian              5             402.0
# 14        Commercial           German            186             384.5
# 114     HashtagGamer         Romanian              2            2382.0
# 64        Fearmonger  Farsi (Persian)             45              50.0
# 102     HashtagGamer          Italian              8            2351.0
#
#      followers_max
# 11             858
# 56              53
# 221          92491
# 9              858
# 132            960
# 301           3441
# 14             850
# 114          24570
# 64              54
# 102          24541

# %% [markdown]
# To start, we can sort `new_cat_lang` based on the median number of followers.

# %%
new_cat_lang.sort_values('followers_median', ascending=False)[:10]
# Out:
#     account_category            language  followers_min  followers_median  \
# 242       NonEnglish  LANGUAGE UNDEFINED              0           26395.0
# 178         NewsFeed              Arabic              0           20700.0
# 213         NewsFeed             Turkish          18603           19685.0
# 209         NewsFeed              Somali             10           19622.0
# 188         NewsFeed             Finnish          12288           19035.5
# 292       RightTroll  LANGUAGE UNDEFINED              0           17448.0
# 215         NewsFeed               Uzbek              6           17026.0
# 216         NewsFeed          Vietnamese           1136           16555.0
# 177         NewsFeed            Albanian              7           16110.0
# 183         NewsFeed              Danish          12140           15565.0
#
#      followers_max
# 242         251275
# 178          33185
# 213          20994
# 209          31854
# 188          25733
# 292          32459
# 215          27637
# 216          61661
# 177          31813
# 183          18792

# %% [markdown]
# Using the same criteria, we can also rank the account groups based on which have the greatest number of median followers. The account with most followers will be given a rank of 1.

# %%
new_cat_lang['followers_median'].rank(method='max')
# Out:
# 0      130.0
# 1      140.0
# 2      123.0
# 3      155.0
# 4      151.0
#        ...
# 347     66.0
# 348     16.0
# 349     81.0
# 350     59.0
# 351     35.0
# Name: followers_median, Length: 352, dtype: float64

# %% [markdown]
# If we were to save this value as a new column, we could use it later on for filtering, conducting more analyses, or highlighting important accounts in a visualization. More on this later.
#
# ## Breaking Ties
# Consider the sort below.

# %%
new_cat_lang.sort_values('followers_median', ascending=True)[:10]
# Out:
#     account_category            language  followers_min  followers_median  \
# 155        LeftTroll  LANGUAGE UNDEFINED              0               0.0
# 345          Unknown             Swedish              0               0.0
# 282       RightTroll            Gujarati              0               0.0
# 71        Fearmonger  LANGUAGE UNDEFINED              0               0.0
# 268       RightTroll             Bengali              1               1.0
# 269       RightTroll           Bulgarian              1               1.0
# 327          Unknown              German              0               7.0
# 214         NewsFeed                Urdu             10              10.0
# 340          Unknown             Russian              0              12.0
# 249       NonEnglish          Portuguese              0              18.0
#
#      followers_max
# 155            622
# 345              0
# 282             11
# 71               0
# 268              1
# 269              1
# 327            220
# 214             10
# 340           6343
# 249           4348

# %% [markdown]
# As you can see, there are multiple account groups with 0 followers. In these cases it might be useful to break the tie using another column.
#
# To do this, we can specify multiple columns to be used during sorting. The importance of the columns in the sort is determined by the order in which they are provided. For example, in the cell below the `followers_median` column will be used to sort the data first, then the `followers_max` column will only be used to break ties in the original sort.

# %%
new_cat_lang.sort_values(['followers_median', 'followers_max'], 
                         ascending=True)[:10]
# Out:
#     account_category            language  followers_min  followers_median  \
# 71        Fearmonger  LANGUAGE UNDEFINED              0               0.0
# 345          Unknown             Swedish              0               0.0
# 282       RightTroll            Gujarati              0               0.0
# 155        LeftTroll  LANGUAGE UNDEFINED              0               0.0
# 268       RightTroll             Bengali              1               1.0
# 269       RightTroll           Bulgarian              1               1.0
# 327          Unknown              German              0               7.0
# 214         NewsFeed                Urdu             10              10.0
# 340          Unknown             Russian              0              12.0
# 249       NonEnglish          Portuguese              0              18.0
#
#      followers_max
# 71               0
# 345              0
# 282             11
# 155            622
# 268              1
# 269              1
# 327            220
# 214             10
# 340           6343
# 249           4348

# %% [markdown]
# <a id='corr'></a>
# #  <i class="fa fa-location-arrow"></i> Correlation and Covariance
# Sometimes it is useful to calculate the correlation between numeric columns in a `DataFrame`. To do this you can use the `.corr()` method, which by default calculates the Pearson correlation coefficient, ignoring any missing (NA or null) values.
#
# $$\rho_{x,y} = \frac{\text{cov}(x,y)}{\sigma_x \sigma_y}$$

# %%
df.corr()
# Out:
#                following  followers   updates   retweet  new_june_2018  \
# following       1.000000   0.580259  0.151950 -0.305094      -0.150726
# followers       0.580259   1.000000  0.233705 -0.312036      -0.049159
# updates         0.151950   0.233705  1.000000 -0.171920       0.119216
# retweet        -0.305094  -0.312036 -0.171920  1.000000       0.116437
# new_june_2018  -0.150726  -0.049159  0.119216  0.116437       1.000000
# tweet_id        0.110589   0.086571  0.149430 -0.027388      -0.353891
#
#                tweet_id
# following      0.110589
# followers      0.086571
# updates        0.149430
# retweet       -0.027388
# new_june_2018 -0.353891
# tweet_id       1.000000

# %% [markdown]
# Additionally, if you are interested in finding the correlation between two specific columns you can use the `.corr()` method for `Series`.

# %%
df['followers'].corr(df['following'])
# Out:
# 0.5802587806116529

# %% [markdown]
# Look at the [documentation]() for the `corr()` method. In the cell below use the `.corr()` method to find the spearman rank correlation between any two columns in the `DataFrame`.

# %%
# Your Answer Here

# %% [markdown]
# Additionally, we can calculate the pairwise covariance between columns using the `.cov()` method.
#
# $$ \mbox{cov}_{x,y}=\frac{\sum_{i=1}^{N}(x_{i}-\bar{x})(y_{i}-\bar{y})}{N-1}$$
#
# Once again, this can be applied to entire `DataFrames`

# %%
df.cov()
# Out:
#                   following     followers       updates       retweet  \
# following      3.164787e+07  4.777653e+07  1.513500e+07 -8.520629e+02
# followers      4.777653e+07  2.142107e+08  6.056168e+07 -2.267201e+03
# updates        1.513500e+07  6.056168e+07  3.134863e+08 -1.511126e+03
# retweet       -8.520629e+02 -2.267201e+03 -1.511126e+03  2.464509e-01
# new_june_2018 -3.451090e+02 -2.928336e+02  8.590936e+02  2.352615e-02
# tweet_id       6.002876e+19  1.222554e+20  2.552837e+20 -1.311904e+15
#
#                new_june_2018      tweet_id
# following      -3.451090e+02  6.002876e+19
# followers      -2.928336e+02  1.222554e+20
# updates         8.590936e+02  2.552837e+20
# retweet         2.352615e-02 -1.311904e+15
# new_june_2018   1.656500e-01 -1.389762e+16
# tweet_id       -1.389762e+16  9.310034e+33

# %% [markdown]
# Or to individual columns.

# %%
df['followers'].cov(df['following'])
# Out:
# 47776527.55856115

# %%
df['following'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <a id='date'></a>
# #  <i class="fa fa-location-arrow"></i> Dates and Times
# Many real world datasets include a temporal component, including the Russian Trolls dataset. Often, strings are used to store dates and times. However, strings don't take advantage of the unique properties of time.
#
# For example, it becomes difficult to sort dates if they are stored in strings with strange formats. This is because strings are sorted alphabetically, rather than based on what the string actually represents.

# %%
"Monday Mar 2, 1999" > "Friday Feb 21, 2020"
# Out:
# True

# %% [markdown]
# Additionally, it is often tedious to extract features of the date string such as day of the week, month, or timezone.
#
# This is why pandas and Python have implemented special types for date/time objects, called [`Timestamp`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html) and [`Datetime`](https://docs.python.org/2/library/datetime.html), respectively. These two types are essentially equivalent to one another.
#
# We can convert date strings from a column or `Series` into Timestamps using the `to_datetime` function.

# %%
small_df['publish_date']
# Out:
# 2076447    4/27/2016 15:10
# 945352      5/13/2015 7:12
# 476141     5/29/2016 15:05
# 2242967     2/22/2015 9:57
# 1149978    6/18/2017 18:38
#                 ...
# 847503     5/15/2015 11:32
# 2672760      8/6/2017 6:23
# 1486301      2/2/2017 7:21
# 140158     12/3/2015 12:05
# 458654     3/17/2015 14:45
# Name: publish_date, Length: 1000, dtype: object

# %%
small_df['dt_publish_date'] = pd.to_datetime(small_df['publish_date'])
small_df['dt_harvested_date'] = pd.to_datetime(small_df['harvested_date'])

small_df.sample(5)
# Out:
#         external_author_id           author  \
# 348227          2951556370    SPECIALAFFAIR
# 2180889         2630842499    DAILYSANDIEGO
# 1719114         3071479646  BALTIMORE0NLINE
# 475147          3899481526     TODAYINSYRIA
# 2391112         2440755969     ANWARJAMIL22
#
#                                                    content          region  \
# 348227   Japan urges China not to escalate East China S...   United States
# 2180889  #politics Trump Vows to Undo Any Executive Act...   United States
# 1719114  #Breaking: Adapted Sports Festival offers scub...   United States
# 475147   #IslamicState executes 45 of its own militants...  United Kingdom
# 2391112  Путин проведет ряд двусторонних встреч на поля...          Israel
#
#         language      publish_date    harvested_date  following  followers  \
# 348227   English     8/8/2016 4:23     8/8/2016 4:23      10135      11261
# 2180889  English    1/3/2016 13:59    1/3/2016 13:59       7873      12262
# 1719114  English   9/14/2016 13:09   9/14/2016 13:10       4924       6321
# 475147   English   5/11/2016 13:04   5/11/2016 13:04       5276      18582
# 2391112  Russian  11/14/2015 22:51  11/14/2015 22:51          1        250
#
#          updates  ...                                         tco2_step1  \
# 348227     30933  ...                                                NaN
# 2180889    10390  ...                                                NaN
# 1719114    10535  ...                                                NaN
# 475147      4733  ...  http://aranews.net/2016/05/islamic-state-burie...
# 2391112     2243  ...       http://ria.ru/world/20151115/1320741316.html
#
#         tco3_step1  empty_tweet followers_more_1000  len_tweet num_hashtags  \
# 348227         NaN        False                True         63            1
# 2180889        NaN        False                True         57            1
# 1719114        NaN        False                True        119            1
# 475147         NaN        False                True        133            2
# 2391112        NaN        False               False        113            1
#
#          followers_following_ratio following_followers_2     dt_publish_date  \
# 348227                    1.111100              1.111100 2016-08-08 04:23:00
# 2180889                   1.557475              1.557475 2016-01-03 13:59:00
# 1719114                   1.283712              1.283712 2016-09-14 13:09:00
# 475147                    3.521986              3.521986 2016-05-11 13:04:00
# 2391112                 250.000000            250.000000 2015-11-14 22:51:00
#
#           dt_harvested_date
# 348227  2016-08-08 04:23:00
# 2180889 2016-01-03 13:59:00
# 1719114 2016-09-14 13:10:00
# 475147  2016-05-11 13:04:00
# 2391112 2015-11-14 22:51:00
#
# [5 rows x 29 columns]

# %% [markdown]
# Lets check the type associated with the `dt_publish_date` column.

# %%
small_df['dt_publish_date']
# Out:
# 67381    2017-08-17 01:07:00
# 125501   2016-01-25 13:58:00
# 100647   2015-07-06 15:21:00
# 45562    2017-04-23 18:02:00
# 164634   2016-03-14 22:18:00
#                  ...
# 146044   2015-12-17 22:33:00
# 146881   2015-07-05 16:47:00
# 33284    2015-07-19 20:53:00
# 115749   2015-08-08 10:13:00
# 195851   2016-07-30 09:30:00
# Name: dt_publish_date, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# Now that the column is stored in a datetime specific format, we can  access temporal specific attributes such as month,

# %%
small_df['dt_publish_date'].dt.month
# Out:
# 67381      8
# 125501     1
# 100647     7
# 45562      4
# 164634     3
#           ..
# 146044    12
# 146881     7
# 33284      7
# 115749     8
# 195851     7
# Name: dt_publish_date, Length: 1000, dtype: int64

# %% [markdown]
# Sort a `DataFrame` based on `publish_date`,

# %%
small_df.sort_values(['dt_publish_date'])
# Out:
#         external_author_id           author  \
# 119988           480763276          IRIS0_O
# 182778          2569229674       LORAGREEEN
# 79419           2732675512      BGARNER2107
# 76825           2535529153    BEVERLYBALSOM
# 122091          2753286467     ISRAEL_WILLS
# ...                    ...              ...
# 164693  743167000000000000  COVFEFENATIONUS
# 166165  743167000000000000  COVFEFENATIONUS
# 166219  743167000000000000  COVFEFENATIONUS
# 180374  743167000000000000  COVFEFENATIONUS
# 27437   905141000000000000     KANIJJACKSON
#
#                                                   content         region  \
# 119988  God save da Ukraine #ТвимперияЛюбитВас http://...  United States
# 182778           God just laughs at my plans  #true #love     Azerbaijan
# 79419   No one has ever become poor by giving. – Anne ...  United States
# 76825   is it true that 2 units of Zaporozhia NPP shut...  United States
# 122091  parents: why don't you come socialize with the...  United States
# ...                                                   ...            ...
# 164693    #FollowTheWhiteRabbit 🐇 https://t.co/mDulWjWcpC  United States
# 166165  '@tbailey5477 @RSutton57 @redhead4645 @Jali_Ca...  United States
# 166219  When your RINO contract expires w/ @CNN Ana, y...  United States
# 180374  '@shannoneffects1 @davis1988will @GrizzleMeist...  United States
# 27437   This is your daily reminder that the NRA is un...  United States
#
#          language      publish_date    harvested_date  following  followers  \
# 119988  Bulgarian   6/21/2014 13:07   6/21/2014 13:07       1637       2390
# 182778    English  11/10/2014 14:26  11/10/2014 14:26        135         15
# 79419     English  12/15/2014 15:02  12/15/2014 15:02          0          0
# 76825     English    1/3/2015 20:35   1/30/2015 17:23        555        107
# 122091    English     1/8/2015 9:52     1/8/2015 9:53        185         14
# ...           ...               ...               ...        ...        ...
# 164693    English  11/13/2017 21:05  11/13/2017 21:06        246       2169
# 166165    English  11/15/2017 22:38  11/15/2017 22:38        246       2196
# 166219    English  11/15/2017 22:45  11/15/2017 22:46        246       2196
# 180374    English    12/4/2017 0:25    12/4/2017 0:25        249       2572
# 27437     English   2/27/2018 21:14   2/27/2018 21:14       6592      15774
#
#         updates  ...            tweet_id  \
# 119988     4541  ...  480336235555454976
# 182778      278  ...  531815161296728064
# 79419       152  ...  544507759358533633
# 76825       173  ...  551476965178220545
# 122091      170  ...  553127216398483456
# ...         ...  ...                 ...
# 164693   145861  ...  930179955647848449
# 166165   147323  ...  930928064480997376
# 166219   147386  ...  930929655065931776
# 180374   160131  ...  937477933580484608
# 27437      2383  ...  968595104196939782
#
#                                               article_url  \
# 119988  http://twitter.com/iris0_o/statuses/4803362355...
# 182778  http://twitter.com/LoraGreeen/statuses/5318151...
# 79419   http://twitter.com/BGarner2107/statuses/544507...
# 76825   http://twitter.com/BeverlyBalsom/statuses/5514...
# 122091  http://twitter.com/Israel_Wills/statuses/55312...
# ...                                                   ...
# 164693  http://twitter.com/743166519157227520/statuses...
# 166165  http://twitter.com/743166519157227520/statuses...
# 166219  http://twitter.com/743166519157227520/statuses...
# 180374  http://twitter.com/743166519157227520/statuses...
# 27437   http://twitter.com/905141386781085696/statuses...
#
#                                                tco1_step1  \
# 119988  https://twitter.com/essyKrac/status/4803316963...
# 182778                                                NaN
# 79419                                                 NaN
# 76825                                                 NaN
# 122091                                                NaN
# ...                                                   ...
# 164693  https://twitter.com/TrumpTrain45Pac/status/929...
# 166165  https://twitter.com/WendyKeel4/status/93059441...
# 166219  https://twitter.com/ananavarro/status/93062410...
# 180374                                                NaN
# 27437                                                 NaN
#
#                    tco2_step1  tco3_step1 empty_tweet  num_hashtags  \
# 119988  http://bit.ly/1nrfHbX         NaN       False             1
# 182778                    NaN         NaN       False             2
# 79419                     NaN         NaN       False             0
# 76825                     NaN         NaN       False             2
# 122091                    NaN         NaN       False             0
# ...                       ...         ...         ...           ...
# 164693                    NaN         NaN       False             1
# 166165                    NaN         NaN       False             0
# 166219    http://ancestry.com         NaN       False             1
# 180374                    NaN         NaN       False             0
# 27437                     NaN         NaN       False             1
#
#        followers_following_ratio     dt_publish_date   dt_harvested_date
# 119988                  1.459988 2014-06-21 13:07:00 2014-06-21 13:07:00
# 182778                  0.111111 2014-11-10 14:26:00 2014-11-10 14:26:00
# 79419                        NaN 2014-12-15 15:02:00 2014-12-15 15:02:00
# 76825                   0.192793 2015-01-03 20:35:00 2015-01-30 17:23:00
# 122091                  0.075676 2015-01-08 09:52:00 2015-01-08 09:53:00
# ...                          ...                 ...                 ...
# 164693                  8.817073 2017-11-13 21:05:00 2017-11-13 21:06:00
# 166165                  8.926829 2017-11-15 22:38:00 2017-11-15 22:38:00
# 166219                  8.926829 2017-11-15 22:45:00 2017-11-15 22:46:00
# 180374                 10.329317 2017-12-04 00:25:00 2017-12-04 00:25:00
# 27437                   2.392900 2018-02-27 21:14:00 2018-02-27 21:14:00
#
# [1000 rows x 26 columns]

# %% [markdown]
# and add or subtract datetime columns to create new columns.

# %%
small_df['days_until_harvest'] = small_df['dt_harvested_date'] - small_df['dt_publish_date']
small_df.sample(5)
# Out:
#          external_author_id           author  \
# 2512920          2882037326       DANAGEEZUS
# 1121080          1930747698        NEVNOV_RU
# 1355103          1694026190  JACQUELINISBEST
# 2554442  892000000000000000        DEBESSTRS
# 1017174          1727482238   MELVINSROBERTS
#
#                                                    content         region  \
# 2512920  #SecondhandGifts A book. With a note -- to som...  United States
# 1121080  Машина сбила пешехода на проспекте Обуховской ...  United States
# 1355103  Mitt the Shit/running mate losers/ Dont want t...  United States
# 2554442  RT DebAlwaystrump: America is pissed😠 FBI neve...        Unknown
# 1017174  Win lottery. Marry nymphomaniac.  #WhatIWantFo...  United States
#
#                 language      publish_date    harvested_date  following  \
# 2512920          English  12/21/2016 16:10  12/21/2016 16:10      13372
# 1121080          Russian   2/11/2017 21:48   2/11/2017 21:48      16728
# 1355103          English   12/4/2016 19:22   12/4/2016 19:22       2201
# 2554442          English   8/12/2017 11:27   8/12/2017 11:27       1722
# 1017174  Farsi (Persian)   11/24/2016 8:27   11/24/2016 8:27       2996
#
#          followers  updates  ... tco3_step1 empty_tweet  followers_more_1000  \
# 2512920      22707    14894  ...        NaN       False                 True
# 1121080      25029    33843  ...        NaN       False                 True
# 1355103       2153     4270  ...        NaN       False                 True
# 2554442       1612     8481  ...        NaN       False                 True
# 1017174       3401     5217  ...        NaN       False                 True
#
#         len_tweet  num_hashtags followers_following_ratio  \
# 2512920        82             1                  1.698101
# 1121080       102             0                  1.496234
# 1355103       135             0                  0.978192
# 2554442       139             0                  0.936121
# 1017174        64             1                  1.135180
#
#          following_followers_2     dt_publish_date   dt_harvested_date  \
# 2512920               1.698101 2016-12-21 16:10:00 2016-12-21 16:10:00
# 1121080               1.496234 2017-02-11 21:48:00 2017-02-11 21:48:00
# 1355103               0.978192 2016-12-04 19:22:00 2016-12-04 19:22:00
# 2554442               0.936121 2017-08-12 11:27:00 2017-08-12 11:27:00
# 1017174               1.135180 2016-11-24 08:27:00 2016-11-24 08:27:00
#
#         days_until_harvest
# 2512920             0 days
# 1121080             0 days
# 1355103             0 days
# 2554442             0 days
# 1017174             0 days
#
# [5 rows x 30 columns]

# %% [markdown]
# ## <font color="crimson"><i class="fa fa-user"></i> YOUR TURN!</font>
#
# In the cell below use methods found [here](https://pandas.pydata.org/pandas-docs/stable/reference/series.html) to create a new column called `weekend`. It should be `True` if the tweet was published on a Saturday or Sunday & `False` otherwise.

# %%
# Your Answer Here

# %% [markdown]
# <a id='miss'></a>
# #  <i class="fa fa-location-arrow"></i> Missing Data
#
# Missing data is a common occurrence when working with real-world datasets. Data can be missing for multiple reasons.
#
# ## <font color="crimson"><i class="fa fa-user"></i> YOUR TURN!</font>
#
#
# What are some of the reasons you are familiar with? Try to think of at least 3.

# %%
# Your answer here
#
#
#

# %% [markdown]
# Once you recognize that any `Series` or `DataFrame` corresponding to a real-world dataset is likely to have missing values, you're probably wondering how these missing data are stored in pandas.
#
# Generally, pandas uses the `np.nan` value to represent missing data. See the table below for some examples of rows containing missing data (Scroll to the far right columns).

# %%
df.head(5)
# Out:
#   external_author_id          author  \
# 0         2260338140  POLITICS_T0DAY
# 1         2260338140  POLITICS_T0DAY
# 2         2260338140  POLITICS_T0DAY
# 3         2260338140  POLITICS_T0DAY
# 4         2260338140  POLITICS_T0DAY
#
#                                              content         region language  \
# 0                            https://t.co/9OgJ5RxUEV  United States  Russian
# 1  Пять этажей жилого дома рухнули в Ярославле по...  United States  Russian
# 2  Вербовщика Джихади Джона нашли в Турции через ...  United States  Russian
# 3  "Война" с Евгением Поддубным от 14.02.16 https...  United States  Russian
# 4  Посол #САР в #РФ обвинил #США в авиаударах по ...  United States  Russian
#
#       publish_date   harvested_date  following  followers  updates  ...  \
# 0  2/16/2016 23:15  2/16/2016 23:16         92        887    12939  ...
# 1   2/16/2016 5:41   2/16/2016 5:42         92        884    12895  ...
# 2   2/16/2016 6:10   2/16/2016 6:10         92        884    12896  ...
# 3   2/16/2016 6:36   2/16/2016 6:36         92        885    12897  ...
# 4   2/16/2016 7:01   2/16/2016 7:01         92        885    12898  ...
#
#   account_type retweet  account_category new_june_2018  alt_external_id  \
# 0      Russian       0        NonEnglish             0       2260338140
# 1      Russian       0        NonEnglish             0       2260338140
# 2      Russian       0        NonEnglish             0       2260338140
# 3      Russian       0        NonEnglish             0       2260338140
# 4      Russian       0        NonEnglish             0       2260338140
#
#              tweet_id                                        article_url  \
# 0  699733931055259648  http://twitter.com/politics_t0day/statuses/699...
# 1  699468718888390656  http://twitter.com/politics_t0day/statuses/699...
# 2  699476018063659008  http://twitter.com/politics_t0day/statuses/699...
# 3  699482457377210372  http://twitter.com/politics_t0day/statuses/699...
# 4  699488793993330688  http://twitter.com/politics_t0day/statuses/699...
#
#                                           tco1_step1  \
# 0  https://twitter.com/politics_t0day/status/6997...
# 1                       https://youtu.be/STxTIceQmsA
# 2                       https://youtu.be/xy5ap3xX_fs
# 3                       https://youtu.be/a7x4v7CYHiA
# 4  https://twitter.com/politics_t0day/status/6994...
#
#                             tco2_step1 tco3_step1
# 0                                  NaN        NaN
# 1                                  NaN        NaN
# 2                                  NaN        NaN
# 3                                  NaN        NaN
# 4  https://vk.com/wall-62675857_176796        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# NumPy's `np.nan` value is a special case of a floating point number representing an unrepresentable value. These kinds of values are called `NaNs` (Not a Number).

# %%
type(np.nan)
# Out:
# float

# %% [markdown]
# `np.nan` cannot be used in equality tests, since any comparison to a `np.nan` value will evaluate as `False`. This includes comparing `np.nan` to itself.

# %%
n = np.nan
n == n
# Out:
# False

# %% [markdown]
# As well, `np.nan` values do not evaluate to `False` or `None`. This makes it difficult to distinguish missing values. Luckily, we can use the `np.isna()` function for this purpose. This is especially useful in control flow.

# %%
if np.nan is None:
    print('NaN is None')
if np.nan:
    print('NaN evaluates to True in control flow')
if np.isnan(np.nan):
    print('NaN is considered a NaN value in NumPy')
# Out:
# NaN evaluates to True in control flow
# NaN is considered a NaN value in NumPy

# %% [markdown]
# Additionally, `np.nan` values are generally excluded from pandas functions that perform calculations over dataframes, rows, or columns. For example, documentation often stipulates that a calculation is done over all values, excluding NaN or NULL values.

# %%
total = len(df['tco1_step1'])
count = df['tco1_step1'].count()
print('Total: {}'.format(total))
print('Count: {}'.format(count))
print(' Diff:  {}'.format(total-count))
# Out:
# Total: 2946207
# Count: 2100236
#  Diff:  845971

# %% [markdown]
# The total number of items in the `tco1_step` column is nearly 85000 more than the counts received from the `count()` function. If what we learned above is correct, this difference should be accounted for when we discover how many items in this column are NaNs.

# %%
nans = df['tco1_step1'].isna().sum()
print(' NaNs: {}'.format(nans))
# Out:
#  NaNs: 845971

# %% [markdown]
# The `.isna()` method can be useful in transforming and filtering data.
#
# ## <font color="crimson"><i class="fa fa-user"></i> YOUR TURN!</font>
#
# Use the `.isna()` function, along with the methods we covered in the filtering section to only show rows in `df` where the region column is not missing. Save the resulting `DataFrame` as `region_df`.

# %%
# Your Answer Here

# %%
# Run this cell to check
if len(region_df) >= len(df):
    print('Nothing was filtered out, try again!')
else:
    print('At least one value was filtered out of the DataFrame. It is up to you to make sure the right values were removed!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-7386297edd2a> in <module>
#       1 # Run this cell to check
# ----> 2 if len(region_df) >= len(df):
#       3     print('Nothing was filtered out, try again!')
#       4 else:
#       5     print('At least one value was filtered out of the DataFrame. It is up to you to make sure the right values were removed!')
#
# NameError: name 'region_df' is not defined

# %% [markdown]
# <a id='multi'></a>
# #  <i class="fa fa-location-arrow"></i> Working with Multiple Datasets
# Some of the most interesting analysis comes from combining datasets.
#
# <a id='concat'></a>
# ## Concatenating
# Sometimes, we will want to concatenate (append) `DataFrames`. This works much the same as list concatenation &mdash; one `DataFrame` is added to the end of a previous `DataFrame`. Typically, concatenation grows the number of rows in a `DataFrame` without adding many (if any) columns.
#
# In fact, we used concatenation when we originally read in the Russian Trolls dataset. There are 12 smaller datasets that make up the larger Russian Trolls dataset we have been using. Below, I'll load in two of them.

# %%
df1= pd.read_csv('data/russian-troll-tweets/IRAhandle_tweets_1.csv')
print('df1 has {} rows and {} columns'.format(len(df1), len(df1.columns)))
# Out:
# df1 has 243891 rows and 21 columns

# %%
df2 = pd.read_csv('data/russian-troll-tweets/IRAhandle_tweets_2.csv')
print('df2 has {} rows and {} columns'.format(len(df2), len(df2.columns)))
# Out:
# df2 has 250520 rows and 21 columns

# %% [markdown]
# Both `DataFrames` have 21 columns. If you look into it you will see these columns are the same between the two dataframes.
#
# We can concatenate the `DataFrames`.

# %%
con = pd.concat([df1, df2])
print('con has {} rows and {} columns'.format(len(con), len(con.columns)))
# Out:
# con has 494411 rows and 21 columns

# %% [markdown]
# When we concatenate the two `DataFrames` there continues to be only 21 columns, but the number of rows has increased, accounting for the rows in both the original `DataFrames`. Check out the concatenated `DataFrame` below.

# %%
con.sample(5)
# Out:
#         external_author_id          author  \
# 43584   892000000000000000        BEEATRWL
# 69581           2586506586  ALEXHARRITONOV
# 23457           1652138929        ACEJINEV
# 142396          2178836894  BOEING_IS_BACK
# 63512   725000000000000000      BERLINBOTE
#
#                                                   content         region  \
# 43584   I liked a YouTube video https://t.co/SrrKUzGK1...        Unknown
# 69581   Мхитарян в январе вернется в «Боруссию»? https...     Azerbaijan
# 23457   #TheResistance #fucktrump https://t.co/VymUEhA5Rs  United States
# 142396     Крым скоро будет продан http://t.co/XUDdMXVFdS       Malaysia
# 63512   Wird gegen Polizeipräsident Kandt und Vize Kop...        Unknown
#
#        language     publish_date   harvested_date  following  followers  \
# 43584   English  8/14/2017 18:55  8/14/2017 18:56       2864        927
# 69581   Russian  11/13/2016 1:44  11/13/2016 1:44        136       2201
# 23457   English   4/15/2017 6:17   4/15/2017 6:17        783        922
# 142396  Russian   8/2/2015 19:53   8/2/2015 19:54       1925       6626
# 63512    German   5/9/2017 16:35   5/9/2017 16:35       1355       1273
#
#         updates  ... account_type retweet  account_category new_june_2018  \
# 43584      1819  ...        Right       0        RightTroll             0
# 69581      2222  ...      Russian       1        NonEnglish             0
# 23457      5885  ...         Left       1         LeftTroll             0
# 142396     1007  ...      Russian       0        NonEnglish             0
# 63512     16634  ...       German       0        NonEnglish             0
#
#            alt_external_id            tweet_id  \
# 43584   891609822109597696  897169846303162370
# 69581           2586506586  797615990846685184
# 23457           1652138929  853130020495249408
# 142396          2178836894  627930217571487745
# 63512   725305686989656064  861982955757064192
#
#                                               article_url  \
# 43584   http://twitter.com/891609822109597696/statuses...
# 69581   http://twitter.com/2586506586/statuses/7976159...
# 23457   http://twitter.com/1652138929/statuses/8531300...
# 142396  http://twitter.com/boeing_is_back/statuses/627...
# 63512   http://twitter.com/725305686989656064/statuses...
#
#                                                tco1_step1  \
# 43584                       http://youtu.be/zISaa1nc1Uo?a
# 69581   http://www.postsovet.ru/blog/kavkaz/834883.htm...
# 23457   https://twitter.com/HaroldWNelson/status/85312...
# 142396                              http://bit.ly/1SxnTwy
# 63512   https://twitter.com/BerlinBote/status/86198295...
#
#                                                tco2_step1 tco3_step1
# 43584                                                 NaN        NaN
# 69581                                                 NaN        NaN
# 23457                                                 NaN        NaN
# 142396                                                NaN        NaN
# 63512   http://www.bz-berlin.de/berlin/wird-gegen-poli...        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## <font color="crimson"><i class="fa fa-user"></i> YOUR TURN!</font>
#
# What would happen if the `DataFrames` did not contain all the same columns? In the cell below, add a new column to one of the `DataFrames` and try concatenating the two `DataFrames`. Was it successful? If so, what was contained in the resulting `DataFrame`.

# %%
# Your Answer Here

# %% [markdown]
# <a id='merge'></a>
# ## Merging
# An alternative way to combine datasets is through merging. If you want to create a `DataFrame` that contains columns from multiple datasets, but is aligned on rows according to some column (or set of columns), you probably want to use the `merge()` function.
#
# We are going to merge two `DataFrames`. One will be the original `df` dataset we have been working with throughout the day.

# %%
print('df has {} rows and {} columns'.format(len(df), len(df.columns)))

df.sample(5)
# Out:
# df has 2946207 rows and 22 columns
#          external_author_id           author  \
# 1985262  892000000000000000         CHAASNTR
# 1384992          1627096807        JASSSCOTT
# 1403873          1653553555  JAYDAASTONISHIN
# 536059           1964340318          EXQUOTE
# 2903554          3438999494  WORLDOFHASHTAGS
#
#                                                    content         region  \
# 1985262  Curated HedgeBz \| ’s Corporate Crime Watchdog...        Unknown
# 1384992  We've been integrating something I created int...  United States
# 1403873  ▶@HWMag: The Strange Story Of George Washingto...  United States
# 536059   http://t.co/OniczTmizl I workout to look good ...  United States
# 2903554       Yada yada blah blah  #MyFarewellWordsWouldBe  United States
#
#         language     publish_date   harvested_date  following  followers  \
# 1985262  English   8/2/2017 12:29   8/2/2017 12:29       1954        643
# 1384992  English  1/19/2017 15:49  1/19/2017 15:50        315        741
# 1403873  English    7/8/2017 4:55    7/8/2017 4:55       1147        891
# 536059   English   7/14/2015 5:22   7/14/2015 5:22          2        236
# 2903554   Arabic  1/11/2017 15:09  1/11/2017 15:09       7522       9225
#
#          updates  ... retweet account_category  new_june_2018  \
# 1985262      840  ...       0       RightTroll              0
# 1384992     4375  ...       1        LeftTroll              0
# 1403873     4934  ...       1        LeftTroll              0
# 536059      9820  ...       0       Commercial              1
# 2903554    26614  ...       1     HashtagGamer              0
#
#             alt_external_id            tweet_id  \
# 1985262  891902187130966017  892723974186074113
# 1384992          1627096807  822108769555533824
# 1403873          1653553555  883550175242985472
# 536059           1964340318  620825661549088768
# 2903554          3438999494  819199588393426945
#
#                                                article_url  \
# 1985262  http://twitter.com/891902187130966017/statuses...
# 1384992  http://twitter.com/1627096807/statuses/8221087...
# 1403873  http://twitter.com/1653553555/statuses/8835501...
# 536059   http://twitter.com/ExQuote/statuses/6208256615...
# 2903554  http://twitter.com/3438999494/statuses/8191995...
#
#                                                 tco1_step1 tco2_step1  \
# 1985262  https://hedgeaccordingly.com/2017/07/dojs-corp...        NaN
# 1384992                                                NaN        NaN
# 1403873                           http://ow.ly/GGj750cFyvN        NaN
# 536059   https://twitter.com/safety/unsafe_link_warning...        NaN
# 2903554                                                NaN        NaN
#
#         tco3_step1 used_to_be_the_index
# 1985262        NaN              1985262
# 1384992        NaN              1384992
# 1403873        NaN              1403873
# 536059         NaN               536059
# 2903554        NaN              2903554
#
# [5 rows x 22 columns]

# %% [markdown]
# The other dataset will be a fake dataset that I created, containing extra information on a subset of authors.

# %%
authors = pd.read_csv('data/fake_author_data.csv')
print('authors has {} rows and {} columns'.format(len(authors), len(authors.columns)))
authors.sample(10)
# Out:
# authors has 298 rows and 3 columns
#               author  coffee_drinker favourite_animal
# 232     ANTHONYCARTR               1             list
# 33         ABUNUWASA               0            Skink
# 141      AMBERLINETR               0             Pike
# 275  ARTEMMPLOTNIKOV               0        Manta ray
# 46      ADELIINESTRT               1             list
# 77          AHNORDYK               1        Damselfly
# 287       ASHLEEYWES               1            Louse
# 251          ARABMTR               1             list
# 249     APRRILSBRUSS               1           Alpaca
# 122     ALIZASSHIELD               0         Landfowl

# %% [markdown]
# To merge these `DataFrames` we need to find a column which can be used to match rows from one `DataFrame` to the other. The columns don't need to have the same name, just values which can be matched with one another. Whatever columns we choose will be called "keys" in our merge.  In our case this will be the `author` columns.
#
# We will use the `merge` function to combine these two `DataFrames`.

# %%
merged = pd.merge(df, authors, on='author')
print('merged has {} rows and {} columns'.format(len(merged), len(merged.columns)))
merged.sample(5)
# Out:
# merged has 243994 rows and 24 columns
#         external_author_id         author  \
# 43662           2526297190       AGITPOLK
# 144524  895000000000000000    ANDRISNABRT
# 5880            3312143142       4MYSQUAD
# 110814          1679279490  AMELIEBALDWIN
# 96562           1679279490  AMELIEBALDWIN
#
#                                                   content         region  \
# 43662   Обстрел консульства, суд в Лондоне, Турецкий п...        Unknown
# 144524  RT JaySekulow: The ACLJ will keep fighting "to...        Unknown
# 5880    Selma 50 event today. See Congressman John Lew...  United States
# 110814  GO TEXAS! #Texas Attorney General first in cou...  United States
# 96562   She didn't show up because somewhere, buried d...  United States
#
#        language      publish_date    harvested_date  following  followers  \
# 43662   Russian   3/29/2017 18:33   3/29/2017 18:33       1171       8917
# 144524  English   8/16/2017 19:30   8/16/2017 19:30         47          7
# 5880    English  10/12/2015 13:27  10/12/2015 13:27       1710       1118
# 110814  English   2/16/2017 11:37   2/16/2017 11:37       2326       2740
# 96562   English    1/22/2017 8:58    1/22/2017 8:58       2340       2727
#
#         updates  ... new_june_2018     alt_external_id            tweet_id  \
# 43662     14129  ...             0          2526297190  847154778815823872
# 144524      645  ...             0  894810803190288385  897903475136319492
# 5880       4180  ...             0          3312143142  653562726984187904
# 110814    29267  ...             0          1679279490  832192195830677504
# 96562     26345  ...             0          1679279490  823092494904791040
#
#                                               article_url  \
# 43662   http://twitter.com/2526297190/statuses/8471547...
# 144524  http://twitter.com/894810803190288385/statuses...
# 5880    http://twitter.com/4mysquad/statuses/653562726...
# 110814  http://twitter.com/1679279490/statuses/8321921...
# 96562   http://twitter.com/1679279490/statuses/8230924...
#
#                                                tco1_step1 tco2_step1  \
# 43662   https://twitter.com/KremlinResident/status/847...        NaN
# 144524                             http://aclj.us/2w1RF75        NaN
# 5880    https://twitter.com/4mysquad/status/6535627269...        NaN
# 110814  https://www.texastribune.org/2017/02/15/ken-pa...        NaN
# 96562   https://twitter.com/bassomar_omy/status/823043...        NaN
#
#         tco3_step1 used_to_be_the_index coffee_drinker favourite_animal
# 43662          NaN              2238537              1              Cow
# 144524         NaN              2339399              0            Viper
# 5880           NaN              2200755              0      Dung beetle
# 110814         NaN              2305689              1          Buzzard
# 96562          NaN              2291437              1          Buzzard
#
# [5 rows x 24 columns]

# %% [markdown]
# You should see a two new columns appear on the far right (`coffee_drinker` and `favourite_animal`). Notice how many rows each of the `DataFrames` have. You can see that the merged `DataFrame` has many fewer rows than the original `df` but many more than `authors`.
#
# By default, rows will only be included in the merged `DataFrame` if their key was present in both datasets. So in our case, if a row's author doesn't appear in the other dataset, that row will not be included in the merged `DataFrame`.
#
# This can be adjusted using the `how` parameter. There are four ways of merging `DataFrames` in pandas &mdash; left, right, outer, and inner. By default, `merge()` uses inner, which only includes a row if its key exists in both `DataFrames`. Check out the [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) to see how the other three methods work.
#
# ## <font color="crimson"><i class="fa fa-user"></i> YOUR TURN!</font>
#
# Choose one of these other methods and use it to re-merge `df` and `authors`. Did it work as expected? Does the result help you understand what was written in the documentation?

# %%
# Your Answer Here

# %% [markdown]
# ### <i class="fa fa-graduation-cap"></i> Record Linkage [<i class="fa fa-forward"></i>](#skip_rl)
#
# Combining datasets is one of the most valuable skills you can have for doing data analytics. In general this process is referred to as "Data Integration" or "Record Linkage".
#
# The `merge` function works great when you can make _exact_ matches between columns. It also works really well because checking for exact matches has been optimized in Pandas. However, its often the case that we need to combine datasets which cannot be merged based on exact matches.
#
# Instead, we often have to use **inexact matching** (aka fuzzy matching or approximate matching) to combine datasets. Typically, this involves using some similarity metric to how close two keys are to one another. Then a match is made based on thresholds, rules, or a nearest-neighbour approach.
#
# However, naively calculating similarity between all possible key combinations results in incredibly lengthy compute times. Instead, there are ways to exclude some key pairs from the beginning. This allows you to drastically reduce the number of comparisons you need to make.
#
# Additionally, inexact matching can leverage machine learning techniques which uses human curated examples to learn to predict whether two rows should be matched with one another.
#
# If this "more advanced" approach to combining datasets is of interest, I highly suggest looking into the [`recordlinkage`](https://github.com/J535D165/recordlinkage) Python package.

# %% [markdown]
# # Regression Models, Network Models, Text Analysis, etc.
#
# There are a variety of packages in Python that can be used to estimate models, including, for example, the [statsmodels](https://www.statsmodels.org/dev/examples/index.html) package for estimating GLMS, logit models, and others. It also provides functions for regression diagnostics, creating coefficient plots, and so on.
#
# There is also a very good machine learning package in Python called [sklearn](https://scikit-learn.org/stable/), which has implementations of regression models, including OLS and logit models.
#
# There is a packaged called [PyStan](https://pystan.readthedocs.io/en/latest/) for doing Bayesian Multilevel Modeling if you are into that kind of thing.
#
# For network analysis, there are a variety of options, the most widely-used of which is [networkx](https://networkx.github.io/).
#
# For natural language processing and text analysis, there are a variety of *outstanding* packages. The most widely-known for natural language processing is the Natural Language Processing Toolkit (NLTK), but for a variety of reasons I recommend you use [spaCy](https://spacy.io/) instead. For topic modelling, [gensim](https://radimrehurek.com/gensim/) has very good implementations of common models.
#
# For most machine learning, you will want to use [sklearn](https://scikit-learn.org/stable/). For more advanced stuff (convolutional neural networks for image data), you can check out tensorflow.

# %% [markdown]
# # Jupyter Lab
#
# Not loving the standalone notebooks?
#
# There is a relatively new "IDE" from the Jupyter project called Jupyter Lab. Since some of you have asked about equivalents to RStudio, I thought we would mention it. It's a *bit* more like RStudio, but of course not the same.
#
# PyCharm is another IDE for Python that is RStudio like. It gives you access to multiple panes and lets you execute code line by line.
#
# If you have access to a server and have a iPad or iPhone, I would also suggested checking out the iOS app Juno Connect. It's a beautiful way to execute Python code on a remote server using the notebook formats. What a great way to analyze your data on planes with increasingly narrow seats! :-)

# %% [markdown]
# #  <i class="fa fa-location-arrow"></i> OPEN WORK TIME <a id='open'></a>

# %%
small_df.to_csv('data/data.csv', index=False)
